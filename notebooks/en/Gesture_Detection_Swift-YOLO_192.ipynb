# %% [markdown]
# <a href="https://colab.research.google.com/github/ShadowlessBlu/Dev-Board-Projects/blob/main/notebooks/en/Gesture_Detection_Swift-YOLO_192.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#   <h1>Welcom to SSCMA for Google Colab Training Example 🔥 </h1>
#   <a href="https://sensecraftma.seeed.cc/" target="_blank"><img width="20%" src="https://files.seeedstudio.com/sscma/docs/images/SSCMA-Hero.png"></a>
# </div>

# %% [markdown]
# # Gesture Detection - Swift-YOLO
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/seeed-studio/sscma-model-zoo/blob/main/notebooks/en/Gesture_Detection_Swift-YOLO_192.ipynb)
#
# **Version:** 1.0.0
#
# **Category:** Object Detection
#
# **Algorithm:** [Swift-YOLO](configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py)
#
# **Dataset:** [Gesture](https://universe.roboflow.com/rsp/paper-aaj0p/dataset/33)
#
# **Class:** `paper`, `rock`, `scissors`
#
# ![Gesture Detection](https://files.seeedstudio.com/sscma/static/detection_gesture.png)
#
# The model is a Swift-YOLO model trained on the gesture detection dataset.

# %% [markdown]
# ## ⚙️Prerequisites
# ### Setup SSCMA
# Clone the [repository](https://github.com/Seeed-Studio/ModelAssistant) and install the dependencies.

# %%
# Ethos-U-Vela need to be installed this way, or SSCMA does not work anymore...
# !git clone https://review.mlplatform.org/ml/ethos-u/ethos-u-vela.git
# %cd ethos-u-vela
# !pip install .
# %cd ..

# !git clone https://github.com/Seeed-Studio/ModelAssistant.git   #clone the repo
# %cd ModelAssistant
# !. ./scripts/setup_colab.sh
# Out:
# fatal: destination path 'ethos-u-vela' already exists and is not an empty directory.
# /content/ethos-u-vela
# Processing /content/ethos-u-vela
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: flatbuffers==24.3.25 in /usr/local/lib/python3.10/dist-packages (from ethos-u-vela==4.0.0rc2) (24.3.25)
# Requirement already satisfied: numpy>1.10.0 in /usr/local/lib/python3.10/dist-packages (from ethos-u-vela==4.0.0rc2) (1.26.4)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ethos-u-vela==4.0.0rc2) (4.9.4)
# Building wheels for collected packages: ethos-u-vela
#   Building wheel for ethos-u-vela (pyproject.toml) ... done
#   Created wheel for ethos-u-vela: filename=ethos_u_vela-4.0.0rc2-cp310-cp310-linux_x86_64.whl size=1556692 sha256=67cd1586a2385d869bc58683b0f0e540129df42c5d2316a68b4b3bd3d4d755f1
#   Stored in directory: /root/.cache/pip/wheels/59/bb/a4/8cbf7845835c564e303787c5b86a3233501a9126e0070abb2d
# Successfully built ethos-u-vela
# Installing collected packages: ethos-u-vela
# Successfully installed ethos-u-vela-4.0.0rc2
# /content
# Cloning into 'ModelAssistant'...
# remote: Enumerating objects: 14554, done.
# remote: Counting objects: 100% (2513/2513), done.
# remote: Compressing objects: 100% (948/948), done.
# remote: Total 14554 (delta 1754), reused 1878 (delta 1550), pack-reused 12041 (from 1)
# Receiving objects: 100% (14554/14554), 24.95 MiB | 25.86 MiB/s, done.
# Resolving deltas: 100% (8518/8518), done.
# /content/ModelAssistant
# Checking if CUDA available... OK
# Collecting torch==2.0.0
#   Downloading torch-2.0.0-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.15.1
#   Downloading torchvision-0.15.1-cp310-cp310-manylinux1_x86_64.whl.metadata (11 kB)
# Collecting torchaudio==2.0.1
#   Downloading torchaudio-2.0.1-cp310-cp310-manylinux1_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.15.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.0)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.0)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.0)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.0)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.0)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.0)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.0)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.0)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.0)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.0)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.0)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.0)
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.1) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0) (71.0.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.0) (0.44.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0) (3.30.2)
# Collecting lit (from triton==2.0.0->torch==2.0.0)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.15.1) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.0) (1.3.0)
# Downloading torch-2.0.0-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.9 MB/s eta 0:00:00
# Downloading torchvision-0.15.1-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 65.1 MB/s eta 0:00:00
# Downloading torchaudio-2.0.1-cp310-cp310-manylinux1_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 64.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 74.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 60.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 43.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 8.9 MB/s eta 0:00:00
# Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 11.3 MB/s eta 0:00:00
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: lit, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0+cu121
#     Uninstalling torch-2.4.0+cu121:
#       Successfully uninstalled torch-2.4.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0+cu121
#     Uninstalling torchvision-0.19.0+cu121:
#       Successfully uninstalled torchvision-0.19.0+cu121
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.4.0+cu121
#     Uninstalling torchaudio-2.4.0+cu121:
#       Successfully uninstalled torchaudio-2.4.0+cu121
# Successfully installed lit-18.1.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.0 torchaudio-2.0.1 torchvision-0.15.1 triton-2.0.0
# Installing base deps... Collecting TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl (from -r requirements/export.txt (line 2))
#   Downloading https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl (416 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.5/416.5 kB 992.3 kB/s eta 0:00:00
# Collecting albumentations<=1.3.1 (from -r requirements/base.txt (line 2))
#   Downloading albumentations-1.3.1-py3-none-any.whl.metadata (34 kB)
# Collecting libusb1 (from -r requirements/base.txt (line 3))
#   Downloading libusb1-3.1.0-py3-none-any.whl.metadata (15 kB)
# Collecting cbor (from -r requirements/base.txt (line 7))
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 8)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 12)) (4.10.0.84)
# Collecting openmim>=0.3.7 (from -r requirements/base.txt (line 16))
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 17)) (24.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 18)) (2.1.4)
# Requirement already satisfied: pillow>=9.4.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 19)) (9.4.0)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 20)) (6.0.2)
# Requirement already satisfied: scikit-image>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 21)) (0.23.2)
# Requirement already satisfied: scikit-learn>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 22)) (1.3.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 26)) (0.12.1)
# Requirement already satisfied: tensorboard>=2.12.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 30)) (2.17.0)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements/base.txt (line 31)) (4.66.5)
# Collecting pyvww (from -r requirements/base.txt (line 35))
#   Downloading pyvww-0.1.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting pnnx==0.0.4 (from -r requirements/inference.txt (line 2))
#   Downloading pnnx-0.0.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting ncnn>=1.0.20230517 (from -r requirements/inference.txt (line 3))
#   Downloading ncnn-1.0.20240820-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (26 kB)
# Collecting onnx>=1.14.0 (from -r requirements/inference.txt (line 4))
#   Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Collecting onnxmltools>=1.11.2 (from -r requirements/inference.txt (line 5))
#   Downloading onnxmltools-1.12.0-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting onnxruntime>=1.15.1 (from -r requirements/inference.txt (line 6))
#   Downloading onnxruntime-1.19.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting onnxsim>=0.4.33 (from -r requirements/inference.txt (line 7))
#   Downloading onnxsim-0.4.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting protobuf>=4.23.3 (from -r requirements/inference.txt (line 8))
#   Downloading protobuf-5.28.0-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: tensorflow>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements/inference.txt (line 9)) (2.17.0)
# Requirement already satisfied: ethos-u-vela in /usr/local/lib/python3.10/dist-packages (from -r requirements/export.txt (line 8)) (4.0.0rc2)
# Collecting black>=23.3.0 (from -r requirements/tests.txt (line 1))
#   Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 7.2 MB/s eta 0:00:00
# Collecting isort>=5.12.0 (from -r requirements/tests.txt (line 2))
#   Downloading isort-5.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting pre-commit>=3.3.3 (from -r requirements/tests.txt (line 3))
#   Downloading pre_commit-3.8.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting ruff>=0.0.275 (from -r requirements/tests.txt (line 4))
#   Downloading ruff-0.6.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from albumentations<=1.3.1->-r requirements/base.txt (line 2)) (1.13.1)
# Collecting qudida>=0.0.4 (from albumentations<=1.3.1->-r requirements/base.txt (line 2))
#   Downloading qudida-0.0.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from albumentations<=1.3.1->-r requirements/base.txt (line 2)) (4.10.0.84)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 16)) (8.1.7)
# Collecting colorama (from openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 16)) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 16)) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 16)) (13.8.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 16)) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->-r requirements/base.txt (line 18)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->-r requirements/base.txt (line 18)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->-r requirements/base.txt (line 18)) (2024.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 21)) (3.3)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 21)) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 21)) (2024.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 21)) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.2->-r requirements/base.txt (line 22)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.2->-r requirements/base.txt (line 22)) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->-r requirements/base.txt (line 26)) (1.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (3.7)
# Collecting protobuf>=4.23.3 (from -r requirements/inference.txt (line 8))
#   Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (71.0.4)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (3.0.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from pyvww->-r requirements/base.txt (line 35)) (2.0.8)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from pyvww->-r requirements/base.txt (line 35)) (0.15.1)
# Collecting portalocker (from ncnn>=1.0.20230517->-r requirements/inference.txt (line 3))
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting coloredlogs (from onnxruntime>=1.15.1->-r requirements/inference.txt (line 6))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.1->-r requirements/inference.txt (line 6)) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.1->-r requirements/inference.txt (line 6)) (1.13.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (1.16.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.37.1)
# Collecting ruamel.yaml>=0.16.12 (from TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->-r requirements/export.txt (line 2))
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting igraph>=0.9 (from TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->-r requirements/export.txt (line 2))
#   Downloading igraph-0.11.6-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ethos-u-vela->-r requirements/export.txt (line 8)) (4.9.4)
# Collecting mypy-extensions>=0.4.3 (from black>=23.3.0->-r requirements/tests.txt (line 1))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black>=23.3.0->-r requirements/tests.txt (line 1))
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black>=23.3.0->-r requirements/tests.txt (line 1)) (4.2.2)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black>=23.3.0->-r requirements/tests.txt (line 1)) (2.0.1)
# Collecting cfgv>=2.0.0 (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3))
#   Downloading cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3))
#   Downloading identify-2.6.0-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3))
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3))
#   Downloading virtualenv-20.26.3-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.44.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->-r requirements/base.txt (line 26)) (2.22)
# Collecting texttable>=1.6.2 (from igraph>=0.9->TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->-r requirements/export.txt (line 2))
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 16)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 16)) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 16)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 16)) (2024.7.4)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.16.12->TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->-r requirements/export.txt (line 2))
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=3.3.3->-r requirements/tests.txt (line 3))
#   Downloading distlib-0.3.8-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (3.15.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.12.3->-r requirements/base.txt (line 30)) (2.1.5)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.15.1->-r requirements/inference.txt (line 6))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting ordered-set (from model-index->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting openxlab (from opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading openxlab-0.1.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools->pyvww->-r requirements/base.txt (line 35)) (3.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim>=0.3.7->-r requirements/base.txt (line 16)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim>=0.3.7->-r requirements/base.txt (line 16)) (2.16.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.15.1->-r requirements/inference.txt (line 6)) (1.3.0)
# Requirement already satisfied: torch==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->pyvww->-r requirements/base.txt (line 35)) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (3.30.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.0->torchvision->pyvww->-r requirements/base.txt (line 35)) (18.1.8)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim>=0.3.7->-r requirements/base.txt (line 16)) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->pyvww->-r requirements/base.txt (line 35)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->pyvww->-r requirements/base.txt (line 35)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->pyvww->-r requirements/base.txt (line 35)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->pyvww->-r requirements/base.txt (line 35)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools->pyvww->-r requirements/base.txt (line 35)) (3.1.4)
# Collecting filelock<4,>=3.12.2 (from virtualenv>=20.10.0->pre-commit>=3.3.3->-r requirements/tests.txt (line 3))
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 18.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pytz>=2020.1 (from pandas>=2.0.0->-r requirements/base.txt (line 18))
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools>=41.0.0 (from tensorboard>=2.12.3->-r requirements/base.txt (line 30))
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm>=4.65.0 (from -r requirements/base.txt (line 31))
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 4.7 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.5 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading aliyun-python-sdk-core-2.15.2.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.5/449.5 kB 37.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16))
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 16)) (43.0.0)
# WARNING: The candidate selected for download or install is a yanked version: 'pnnx' candidate (version 0.0.4 at https://files.pythonhosted.org/packages/2a/61/e70626f1e94026da417e6ecd5ad303d0ef3fe7a32fb3fff821bb07f1f4e2/pnnx-0.0.4-py3-none-any.whl (from https://pypi.org/simple/pnnx/))
# Reason for being yanked: <none given>
# Downloading pnnx-0.0.4-py3-none-any.whl (49.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 MB 7.1 MB/s eta 0:00:00
# Downloading albumentations-1.3.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.7/125.7 kB 10.2 MB/s eta 0:00:00
# Downloading libusb1-3.1.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.6 MB/s eta 0:00:00
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 4.9 MB/s eta 0:00:00
# Downloading pyvww-0.1.1-py3-none-any.whl (8.9 kB)
# Downloading ncnn-1.0.20240820-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 106.1 MB/s eta 0:00:00
# Downloading onnx-1.16.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 106.3 MB/s eta 0:00:00
# Downloading onnxmltools-1.12.0-py2.py3-none-any.whl (329 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.0/329.0 kB 25.7 MB/s eta 0:00:00
# Downloading onnxruntime-1.19.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 101.0 MB/s eta 0:00:00
# Downloading onnxsim-0.4.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 87.4 MB/s eta 0:00:00
# Downloading protobuf-4.25.4-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 25.9 MB/s eta 0:00:00
# Downloading black-24.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 45.0 MB/s eta 0:00:00
# Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 9.1 MB/s eta 0:00:00
# Downloading pre_commit-3.8.0-py2.py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 19.3 MB/s eta 0:00:00
# Downloading ruff-0.6.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 115.8 MB/s eta 0:00:00
# Downloading cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Downloading identify-2.6.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 10.2 MB/s eta 0:00:00
# Downloading igraph-0.11.6-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.5 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 11.0 MB/s eta 0:00:00
# Downloading virtualenv-20.26.3-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 111.7 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 33.6 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 40.3 MB/s eta 0:00:00
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Downloading openxlab-0.1.1-py3-none-any.whl (308 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.6/308.6 kB 26.9 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.6 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 38.4 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.0 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 22.9 MB/s eta 0:00:00
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 53.2 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 13.5 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 81.0 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 9.1 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: cbor, oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp310-cp310-linux_x86_64.whl size=53434 sha256=f42339d1d4e16d9377a8ba6c7ad3bfd19a6e9e02a615cb7bbb48063d23b7b606
#   Stored in directory: /root/.cache/pip/wheels/85/df/c9/b39e40eccaf76dbd218556639a6dc81562226f4c6a64902c85
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=722038e5b968ab84618ec7c2f04bd61cd3eb81dc3b8adfaeb259ab26c8fa2252
#   Stored in directory: /root/.cache/pip/wheels/87/04/7b/7e61b8157fdf211c5131375240d0d86ca82e2a88ead9672c88
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.15.2-py3-none-any.whl size=535313 sha256=958c1cda901fa2865c4cbcb4bb64be85970a0a1de2a6158cdc01a2fceb31b137
#   Stored in directory: /root/.cache/pip/wheels/96/64/cd/d4ec2561e5a29e5272b8e776afb164d339b2fd0d0b616a5bcf
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31407 sha256=1018b70394b222b7a13da7b4967d8719bb5ab8d66c2d9aa8f5c062b49bc20ab6
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built cbor oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: texttable, pytz, pnnx, libusb1, distlib, crcmod, cbor, urllib3, tqdm, setuptools, ruff, ruamel.yaml.clib, pycryptodome, protobuf, portalocker, pathspec, ordered-set, nodeenv, mypy-extensions, jmespath, isort, igraph, identify, humanfriendly, filelock, colorama, cfgv, virtualenv, ruamel.yaml, rich, requests, onnx, model-index, coloredlogs, black, TinyNeuralNetwork, qudida, pre-commit, onnxsim, onnxruntime, onnxmltools, ncnn, aliyun-python-sdk-core, aliyun-python-sdk-kms, albumentations, oss2, openxlab, opendatalab, openmim, pyvww
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.5
#     Uninstalling tqdm-4.66.5:
#       Successfully uninstalled tqdm-4.66.5
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 71.0.4
#     Uninstalling setuptools-71.0.4:
#       Successfully uninstalled setuptools-71.0.4
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.15.4
#     Uninstalling filelock-3.15.4:
#       Successfully uninstalled filelock-3.15.4
#   Attempting uninstall: rich
#     Found existing installation: rich 13.8.0
#     Uninstalling rich-13.8.0:
#       Successfully uninstalled rich-13.8.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.14
#     Uninstalling albumentations-1.4.14:
#       Successfully uninstalled albumentations-1.4.14
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# tensorflow-metadata 1.15.0 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.4 which is incompatible.
# yfinance 0.2.43 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# Successfully installed TinyNeuralNetwork-0.1.1 albumentations-1.3.1 aliyun-python-sdk-core-2.15.2 aliyun-python-sdk-kms-2.16.5 black-24.8.0 cbor-1.0.0 cfgv-3.4.0 colorama-0.4.6 coloredlogs-15.0.1 crcmod-1.7 distlib-0.3.8 filelock-3.14.0 humanfriendly-10.0 identify-2.6.0 igraph-0.11.6 isort-5.13.2 jmespath-0.10.0 libusb1-3.1.0 model-index-0.1.11 mypy-extensions-1.0.0 ncnn-1.0.20240820 nodeenv-1.9.1 onnx-1.16.2 onnxmltools-1.12.0 onnxruntime-1.19.0 onnxsim-0.4.36 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.1 ordered-set-4.1.0 oss2-2.17.0 pathspec-0.12.1 pnnx-0.0.4 portalocker-2.10.1 pre-commit-3.8.0 protobuf-4.25.4 pycryptodome-3.20.0 pytz-2023.4 pyvww-0.1.1 qudida-0.0.4 requests-2.28.2 rich-13.4.2 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 ruff-0.6.3 setuptools-60.2.0 texttable-1.7.0 tqdm-4.65.2 urllib3-1.26.20 virtualenv-20.26.3
# Installing OpenMIM deps...
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu117/torch2.0.0/index.html
# Collecting mmcls>=1.0.0.rc6 (from -r requirements/mmlab.txt (line 2))
#   Downloading mmcls-1.0.0rc6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting mmcv-full<=2.1.0 (from -r requirements/mmlab.txt (line 3))
#   Downloading https://download.openmmlab.com/mmcv/dist/cu117/torch2.0.0/mmcv_full-1.7.2-cp310-cp310-manylinux1_x86_64.whl (70.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 MB 10.9 MB/s eta 0:00:00
# Collecting mmdet<3.1.0,>=3.0.0 (from -r requirements/mmlab.txt (line 4))
#   Downloading mmdet-3.0.0-py3-none-any.whl.metadata (26 kB)
# Collecting mmengine>=0.8.2 (from -r requirements/mmlab.txt (line 5))
#   Downloading mmengine-0.10.4-py3-none-any.whl.metadata (20 kB)
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmcls>=1.0.0.rc6->-r requirements/mmlab.txt (line 2)) (3.7.1)
# Collecting modelindex (from mmcls>=1.0.0.rc6->-r requirements/mmlab.txt (line 2))
#   Downloading modelindex-0.0.2-py3-none-any.whl.metadata (756 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcls>=1.0.0.rc6->-r requirements/mmlab.txt (line 2)) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcls>=1.0.0.rc6->-r requirements/mmlab.txt (line 2)) (24.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmcls>=1.0.0.rc6->-r requirements/mmlab.txt (line 2)) (13.4.2)
# Collecting addict (from mmcv-full<=2.1.0->-r requirements/mmlab.txt (line 3))
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv-full<=2.1.0->-r requirements/mmlab.txt (line 3)) (9.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv-full<=2.1.0->-r requirements/mmlab.txt (line 3)) (6.0.2)
# Collecting yapf (from mmcv-full<=2.1.0->-r requirements/mmlab.txt (line 3))
#   Downloading yapf-0.40.2-py3-none-any.whl.metadata (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv-full<=2.1.0->-r requirements/mmlab.txt (line 3)) (4.10.0.84)
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# ...
# Requirement already satisfied: modelindex in /usr/local/lib/python3.10/dist-packages (from mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (0.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (13.4.2)
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv-full<=2.1.0->sscma==2.0.0rc3) (2.4.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv-full<=2.1.0->sscma==2.0.0rc3) (0.40.2)
# Ignoring mmcv: markers 'extra == "mim"' don't match your environment
# Ignoring mmengine: markers 'extra == "mim"' don't match your environment
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from mmdet<3.1.0,>=3.0.0->sscma==2.0.0rc3) (2.0.8)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from mmdet<3.1.0,>=3.0.0->sscma==2.0.0rc3) (2.0.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mmdet<3.1.0,>=3.0.0->sscma==2.0.0rc3) (1.16.0)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from mmdet<3.1.0,>=3.0.0->sscma==2.0.0rc3) (3.1.10)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.8.2->sscma==2.0.0rc3) (2.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ncnn>=1.0.20230517->sscma==2.0.0rc3) (2.28.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from ncnn>=1.0.20230517->sscma==2.0.0rc3) (2.10.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.1->sscma==2.0.0rc3) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.1->sscma==2.0.0rc3) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.15.1->sscma==2.0.0rc3) (1.13.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->sscma==2.0.0rc3) (0.4.6)
# Requirement already satisfied: model-index in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->sscma==2.0.0rc3) (0.1.11)
# Requirement already satisfied: opendatalab in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->sscma==2.0.0rc3) (0.0.10)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->sscma==2.0.0rc3) (24.1.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim>=0.3.7->sscma==2.0.0rc3) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->sscma==2.0.0rc3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->sscma==2.0.0rc3) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.0->sscma==2.0.0rc3) (2024.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit>=3.3.3->sscma==2.0.0rc3) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit>=3.3.3->sscma==2.0.0rc3) (2.6.0)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from pre-commit>=3.3.3->sscma==2.0.0rc3) (1.9.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit>=3.3.3->sscma==2.0.0rc3) (20.26.3)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->sscma==2.0.0rc3) (3.3)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->sscma==2.0.0rc3) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->sscma==2.0.0rc3) (2024.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.20.0->sscma==2.0.0rc3) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.2->sscma==2.0.0rc3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.2->sscma==2.0.0rc3) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->sscma==2.0.0rc3) (1.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->sscma==2.0.0rc3) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->sscma==2.0.0rc3) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->sscma==2.0.0rc3) (3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->sscma==2.0.0rc3) (60.2.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->sscma==2.0.0rc3) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.12.3->sscma==2.0.0rc3) (3.0.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (1.16.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.12.0->sscma==2.0.0rc3) (0.37.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (3.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch<=2.0.1->sscma==2.0.0rc3) (2.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<=2.0.1->sscma==2.0.0rc3) (0.44.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<=2.0.1->sscma==2.0.0rc3) (3.30.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch<=2.0.1->sscma==2.0.0rc3) (18.1.8)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ethos-u-vela->sscma==2.0.0rc3) (4.9.4)
# Requirement already satisfied: ruamel.yaml>=0.16.12 in /usr/local/lib/python3.10/dist-packages (from TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->sscma==2.0.0rc3) (0.18.6)
# Requirement already satisfied: igraph>=0.9 in /usr/local/lib/python3.10/dist-packages (from TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->sscma==2.0.0rc3) (0.11.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->sscma==2.0.0rc3) (2.22)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from igraph>=0.9->TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->sscma==2.0.0rc3) (1.7.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.12.0->sscma==2.0.0rc3) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow>=2.12.0->sscma==2.0.0rc3) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ncnn>=1.0.20230517->sscma==2.0.0rc3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ncnn>=1.0.20230517->sscma==2.0.0rc3) (3.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ncnn>=1.0.20230517->sscma==2.0.0rc3) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ncnn>=1.0.20230517->sscma==2.0.0rc3) (2024.7.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.16.12->TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->sscma==2.0.0rc3) (0.2.8)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.3.3->sscma==2.0.0rc3) (0.3.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.12.3->sscma==2.0.0rc3) (2.1.5)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.15.1->sscma==2.0.0rc3) (10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (3.1.4)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.10/dist-packages (from model-index->openmim>=0.3.7->sscma==2.0.0rc3) (4.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (3.20.0)
# Requirement already satisfied: openxlab in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (0.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (2.16.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.15.1->sscma==2.0.0rc3) (1.3.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv-full<=2.1.0->sscma==2.0.0rc3) (8.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv-full<=2.1.0->sscma==2.0.0rc3) (3.20.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmcls>=1.0.0.rc6->sscma==2.0.0rc3) (0.1.2)
# Requirement already satisfied: oss2~=2.17.0 in /usr/local/lib/python3.10/dist-packages (from openxlab->opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (2.17.0)
# Requirement already satisfied: crcmod>=1.7 in /usr/local/lib/python3.10/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (2.16.5)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /usr/local/lib/python3.10/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (2.15.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (0.10.0)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->sscma==2.0.0rc3) (43.0.0)
# Building wheels for collected packages: sscma
#   Building editable for sscma (pyproject.toml) ... done
#   Created wheel for sscma: filename=sscma-2.0.0rc3-0.editable-py3-none-any.whl size=11134 sha256=c5e2a8f23edd53fd91c928438ccdba4c1b839a0ab48a50a69d4f3d702dadcc0b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5z4ebt7g/wheels/90/1c/ba/0dcfb496beef1b933cf590042cc252e1a365a514ee48989a82
# Successfully built sscma
# Installing collected packages: sscma
# Successfully installed sscma-2.0.0rc3
# Finished setup... OK

# %% [markdown]
# ### Download the pretrain model weights file

# %%
# %mkdir -p Gesture_Detection_Swift-YOLO_192
# !wget -c https://files.seeedstudio.com/sscma/model_zoo/detection/gesture/swift_yolo_1xb16_300e_coco_sha1_adda465db843aae8384c90c82e223c2cd931cad2.pth -O Gesture_Detection_Swift-YOLO_192/pretrain.pth
# Out:
# --2024-09-04 01:20:02--  https://files.seeedstudio.com/sscma/model_zoo/detection/gesture/swift_yolo_1xb16_300e_coco_sha1_adda465db843aae8384c90c82e223c2cd931cad2.pth
# Resolving files.seeedstudio.com (files.seeedstudio.com)... 18.239.83.19, 18.239.83.38, 18.239.83.26, ...
# Connecting to files.seeedstudio.com (files.seeedstudio.com)|18.239.83.19|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12822891 (12M) [application/octet-stream]
# Saving to: ‘Gesture_Detection_Swift-YOLO_192/pretrain.pth’
#
# Gesture_Detection_S 100%[===================>]  12.23M  10.1MB/s    in 1.2s
#
# 2024-09-04 01:20:04 (10.1 MB/s) - ‘Gesture_Detection_Swift-YOLO_192/pretrain.pth’ saved [12822891/12822891]

# %% [markdown]
# ### Download the dataset

# %%
# %mkdir -p Gesture_Detection_Swift-YOLO_192/dataset
# !wget -c https://universe.roboflow.com/ds/bh7GSv6WTc?key=VefnCP7s9J -O Gesture_Detection_Swift-YOLO_192/dataset.zip
# !unzip -q Gesture_Detection_Swift-YOLO_192/dataset.zip -d Gesture_Detection_Swift-YOLO_192/dataset
# Out:
# --2024-09-04 01:20:23--  https://universe.roboflow.com/ds/bh7GSv6WTc?key=VefnCP7s9J
# Resolving universe.roboflow.com (universe.roboflow.com)... 151.101.1.195, 151.101.65.195, 2620:0:890::100
# Connecting to universe.roboflow.com (universe.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-regional-exports/c8QoUtY71EUIn6gsXQMkSt8K0fC3/5pyuy8c5kxgymGkh4QUa/14/coco.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20240904%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240904T012023Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# --2024-09-04 01:20:24--  https://storage.googleapis.com/roboflow-platform-regional-exports/c8QoUtY71EUIn6gsXQMkSt8K0fC3/5pyuy8c5kxgymGkh4QUa/14/coco.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20240904%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240904T012023Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.127.207, 172.217.218.207, 142.251.31.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.127.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 237876939 (227M) [application/zip]
# Saving to: ‘Gesture_Detection_Swift-YOLO_192/dataset.zip’
#
# Gesture_Detection_S 100%[===================>] 226.86M  28.7MB/s    in 9.0s
#
# 2024-09-04 01:20:33 (25.3 MB/s) - ‘Gesture_Detection_Swift-YOLO_192/dataset.zip’ saved [237876939/237876939]

# %% [markdown]
# ## 🚀Train a model with SSCMA
# All the training parameters are in the `config.py` file, you can change the parameters to train your own model.
#
# Below are explanations of some common parameters. You can also refer to the [documentation](https://sensecraftma.seeed.cc/tutorials/config) for more details.
# - `data_root` - the datasets path.
# - `epochs`- the train epochs. **we use 10 epochs as an example**.
# - `batch_size` - the batch size.
# - `height` - the image height.
# - `width` - the image width.
# - `load_from` - the pretrained model path.
# - `num_classes` - the number of classes.
#
# You can overwrite the parameters in the `config.py` file by using the `--cfg-options` argument.
# ```bash
# # Example
# sscma.train config.py --cfg-options data_root=./datasets/test_dataset epochs=10
# ```

# %%
# !sscma.train configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py \
--cfg-options  \
    work_dir=Gesture_Detection_Swift-YOLO_192 \
    num_classes=3 \
    epochs=10  \
    height=192 \
    width=192 \
    data_root=Gesture_Detection_Swift-YOLO_192/dataset/ \
    load_from=Gesture_Detection_Swift-YOLO_192/pretrain.pth
# Out:
# Using automatically generated input shape (from config 'swift_yolo_tiny_1xb16_300e_coco.py'): [1, 3, 192, 192]
# 09/04 01:34:30 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 40651068
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 40651068
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 09/04 01:34:31 - mmengine - INFO - Config:
# affine_scale = 0.5
# albu_train_transforms = [
#     dict(p=0.01, type='Blur'),
#     dict(p=0.01, type='MedianBlur'),
#     dict(p=0.01, type='ToGray'),
#     dict(p=0.01, type='CLAHE'),
# ]
# anchors = [
#     [
#         (
#             10,
#             13,
#         ),
#         (
#             16,
#             30,
#         ),
#         (
#             33,
#             23,
#         ),
#     ],
#     [
#         (
#             30,
#             61,
#         ),
#         (
#             62,
#             45,
#         ),
#         (
#             59,
#             119,
#         ),
#     ],
#     [
#         (
#             116,
#             90,
#         ),
#         (
#             156,
#             198,
#         ),
#         (
#             373,
#             326,
#         ),
#     ],
# ]
# batch = 16
# batch_shapes_cfg = dict(
#     batch_size=1,
#     extra_pad_ratio=0.5,
#     img_size=192,
#     size_divisor=32,
#     type='BatchShapePolicy')
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0001,
#         priority=49,
#         strict_load=False,
#         type='EMAHook',
#         update_buffers=True),
# ]
# data_root = 'Gesture_Detection_Swift-YOLO_192/dataset/'
# dataset_type = 'sscma.CustomYOLOv5CocoDataset'
# deepen_factor = 0.33
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=100, type='sscma.TextLoggerHook'),
#     param_scheduler=dict(
#         lr_factor=0.01,
#         max_epochs=10,
#         scheduler_type='linear',
#         type='YOLOv5ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='mmdet.DetVisualizationHook'))
# default_scope = 'sscma'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# epochs = 10
# height = 192
# imgsz = (
#     192,
#     192,
# )
# input_type = 'image'
# launcher = 'none'
# load_from = 'Gesture_Detection_Swift-YOLO_192/pretrain.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 0.05
# loss_cls_weight = 0.5
# loss_obj_weight = 1.0
# lr = 0.01
# lr_factor = 0.01
# max_keep_ckpts = 3
# model = dict(
#     backbone=dict(
#         act_cfg=dict(inplace=True, type='ReLU'),
#         deepen_factor=0.33,
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         type='YOLOv5CSPDarknet',
#         widen_factor=0.15),
#     bbox_head=dict(
#         head_module=dict(
#             featmap_strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             in_channels=[
#                 256,
#                 512,
#                 1024,
#             ],
#             num_base_priors=3,
#             num_classes=3,
#             type='sscma.DetHead',
#             widen_factor=0.15),
#         loss_bbox=dict(
#             bbox_format='xywh',
#             eps=1e-07,
#             iou_mode='ciou',
#             loss_weight=0.05,
#             reduction='mean',
#             return_iou=True,
#             type='IoULoss'),
#         loss_cls=dict(
#             loss_weight=0.01875,
#             reduction='mean',
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True),
#         loss_obj=dict(
#             loss_weight=0.09000000000000001,
#             reduction='mean',
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True),
#         obj_level_weights=[
#             4.0,
#             1.0,
#             0.4,
#         ],
#         prior_generator=dict(
#             base_sizes=[
#                 [
#                     (
#                         10,
#                         13,
#                     ),
#                     (
#                         16,
#                         30,
#                     ),
#                     (
#                         33,
#                         23,
#                     ),
#                 ],
#                 [
#                     (
#                         30,
#                         61,
#                     ),
#                     (
#                         62,
#                         45,
#                     ),
#                     (
#                         59,
#                         119,
#                     ),
#                 ],
#                 [
#                     (
#                         116,
#                         90,
#                     ),
#                     (
#                         156,
#                         198,
#                     ),
#                     (
#                         373,
#                         326,
#                     ),
#                 ],
#             ],
#             strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             type='mmdet.YOLOAnchorGenerator'),
#         prior_match_thr=4.0,
#         type='sscma.YOLOV5Head'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             0.0,
#             0.0,
#             0.0,
#         ],
#         std=[
#             255.0,
#             255.0,
#             255.0,
#         ],
#         type='mmdet.DetDataPreprocessor'),
#     neck=dict(
#         act_cfg=dict(inplace=True, type='ReLU'),
#         deepen_factor=0.33,
#         in_channels=[
#             256,
#             512,
#             1024,
#         ],
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         num_csp_blocks=3,
#         out_channels=[
#             256,
#             512,
#             1024,
#         ],
#         type='YOLOv5PAFPN',
#         widen_factor=0.15),
#     test_cfg=dict(
#         max_per_img=300,
#         multi_label=True,
#         nms=dict(iou_threshold=0.65, type='nms'),
#         nms_pre=30000,
#         score_thr=0.001),
#     type='sscma.YOLODetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# momentum = 0.937
# norm_cfg = dict(eps=0.001, momentum=0.03, type='BN')
# num_classes = 3
# num_det_layers = 3
# obj_level_weights = [
#     4.0,
#     1.0,
#     0.4,
# ]
# optim_wrapper = dict(
#     constructor='YOLOv5OptimizerConstructor',
#     optimizer=dict(
#         batch_size_per_gpu=16,
#         lr=0.01,
#         momentum=0.937,
#         nesterov=True,
#         type='SGD',
#         weight_decay=0.0005),
#     type='OptimWrapper')
# param_scheduler = None
# persistent_workers = True
# pre_transform = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
# ]
# prior_match_thr = 4.0
# resume = False
# save_interval = 5
# strides = [
#     8,
#     16,
#     32,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=16,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         batch_shapes_cfg=dict(
#             batch_size=1,
#             extra_pad_ratio=0.5,
#             img_size=192,
#             size_divisor=32,
#             type='BatchShapePolicy'),
#         data_prefix=dict(img='valid/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(scale=(
#                 192,
#                 192,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     192,
#                     192,
#                 ),
#                 type='sscma.LetterResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='sscma.CustomYOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     'Gesture_Detection_Swift-YOLO_192/dataset/valid/_annotations.coco.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# test_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(scale=(
#         192,
#         192,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=False,
#         pad_val=dict(img=114),
#         scale=(
#             192,
#             192,
#         ),
#         type='sscma.LetterResize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'pad_param',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_ann = 'train/_annotations.coco.json'
# train_cfg = dict(max_epochs=10, type='EpochBasedTrainLoop', val_interval=5)
# train_data = 'train/'
# train_dataloader = dict(
#     batch_size=16,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         data_prefix=dict(img='train/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 _scope_='sscma',
#                 img_scale=(
#                     192,
#                     192,
#                 ),
#                 pad_val=114.0,
#                 pre_transform=[
#                     dict(
#                         file_client_args=dict(backend='disk'),
#                         type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                 ],
#                 type='Mosaic'),
#             dict(
#                 border=(
#                     -96,
#                     -96,
#                 ),
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='sscma.CustomYOLOv5CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         _scope_='sscma',
#         img_scale=(
#             192,
#             192,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='Mosaic'),
#     dict(
#         border=(
#             -96,
#             -96,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# val_ann = 'valid/_annotations.coco.json'
# val_batch = 16
# val_cfg = dict(type='ValLoop')
# val_data = 'valid/'
# val_dataloader = dict(
#     batch_size=16,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         batch_shapes_cfg=dict(
#             batch_size=1,
#             extra_pad_ratio=0.5,
#             img_size=192,
#             size_divisor=32,
#             type='BatchShapePolicy'),
#         data_prefix=dict(img='valid/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(scale=(
#                 192,
#                 192,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     192,
#                     192,
#                 ),
#                 type='sscma.LetterResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='sscma.CustomYOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     'Gesture_Detection_Swift-YOLO_192/dataset/valid/_annotations.coco.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# val_interval = 5
# val_workers = 2
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='sscma.FomoLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# weight_decay = 0.0005
# widen_factor = 0.15
# width = 192
# work_dir = 'Gesture_Detection_Swift-YOLO_192'
# workers = 2
#
# ()
# {'vis_backends': [{'type': 'LocalVisBackend'}, {'type': 'TensorboardVisBackend'}], 'save_dir': '/content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/20240904_013429'}
# 2024-09-04 01:34:33.887258: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 01:34:33.923713: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 01:34:33.934472: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-04 01:34:33.960445: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 01:34:35.694767: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 09/04 01:34:39 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 09/04 01:34:39 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_val_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [1, 3, 192, 192]
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::add encountered 24 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::max_pool2d encountered 3 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::sigmoid encountered 3 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::mul encountered 18 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::meshgrid encountered 3 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::clone encountered 3 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::sub encountered 3 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::mul_ encountered 6 time(s)
# 09/04 01:34:41 - mmengine - WARNING - The following submodules of the model were never called during the trace of the graph. They may be unused, or they were accessed by direct calls to .forward() or via other python methods. In the latter case they will have zeros for statistics, though their statistics will still contribute to their parent calling module.
# bbox_head.head_module.data_preprocessor, bbox_head.loss_bbox, bbox_head.loss_cls, bbox_head.loss_obj, data_preprocessor
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::batch_norm encountered 85 time(s)
# 09/04 01:34:41 - mmengine - WARNING - Unsupported operator aten::upsample_nearest2d encountered 2 time(s)
#
# +----------------------------------------------+----------------------+------------+--------------+
# | module                                       | #parameters or shape | #flops     | #activations |
# +----------------------------------------------+----------------------+------------+--------------+
# | model                                        | 0.945M               | 0.126G     | 1.059M       |
# |  backbone                                    |  0.66M               |  0.101G    |  0.868M      |
# |   backbone.stem.conv                         |   1.76K              |   16.22M   |   0.147M     |
# |    backbone.stem.conv.conv                   |    1.728K            |    15.925M |    0.147M    |
# |    backbone.stem.conv.norm                   |    32                |    0.295M  |    0         |
# |   backbone.stage1                            |   9.216K             |   21.234M  |   0.332M     |
# |    backbone.stage1.0.conv                    |    3.504K            |    8.073M  |    55.296K   |
# |    backbone.stage1.1                         |    5.712K            |    13.16M  |    0.276M    |
# |   backbone.stage2                            |   36.56K             |   21.059M  |   0.207M     |
# |    backbone.stage2.0.conv                    |    8.72K             |    5.023M  |    23.04K    |
# |    backbone.stage2.1                         |    27.84K            |    16.036M |    0.184M    |
# |   backbone.stage3                            |   0.188M             |   27.003M  |   0.138M     |
# |    backbone.stage3.0.conv                    |    28.96K            |    4.17M   |    11.52K    |
# |    backbone.stage3.1                         |    0.159M            |    22.833M |    0.127M    |
# |   backbone.stage4                            |   0.425M             |   15.293M  |   43.2K      |
# |    backbone.stage4.0.conv                    |    0.116M            |    4.159M  |    5.76K     |
# |    backbone.stage4.1                         |    0.245M            |    8.813M  |    28.8K     |
# |    backbone.stage4.2                         |    64.48K            |    2.321M  |    8.64K     |
# |  neck                                        |  0.279M              |  23.881M   |  0.173M      |
# |   neck.reduce_layers.2.conv                  |   12.96K             |   0.467M   |   2.88K      |
# |    neck.reduce_layers.2.conv.conv            |    12.8K             |    0.461M  |    2.88K     |
# |    neck.reduce_layers.2.conv.norm            |    0.16K             |    5.76K   |    0         |
# |   neck.top_down_layers                       |   48K                |   10.817M  |   0.109M     |
# |    neck.top_down_layers.0                    |    38.96K            |    5.61M   |    40.32K    |
# |    neck.top_down_layers.1                    |    9.04K             |    5.207M  |    69.12K    |
# |   neck.downsample_layers                     |   72.24K             |   4.164M   |   8.64K      |
# |    neck.downsample_layers.0.conv             |    14.48K            |    2.085M  |    5.76K     |
# |    neck.downsample_layers.1.conv             |    57.76K            |    2.079M  |    2.88K     |
# |   neck.bottom_up_layers                      |   0.145M             |   8.398M   |   51.84K     |
# |    neck.bottom_up_layers.0                   |    29.28K            |    4.216M  |    34.56K    |
# |    neck.bottom_up_layers.1                   |    0.116M            |    4.182M  |    17.28K    |
# |   neck.upsample_layers                       |                      |   34.56K   |   0          |
# |    neck.upsample_layers.0                    |                      |    11.52K  |    0         |
# |    neck.upsample_layers.1                    |                      |    23.04K  |    0         |
# |  bbox_head.head_module.convs_pred            |  6.792K              |  0.968M    |  18.144K     |
# |   bbox_head.head_module.convs_pred.0         |   0.984K             |   0.553M   |   13.824K    |
# |    bbox_head.head_module.convs_pred.0.weight |    (24, 40, 1, 1)    |            |              |
# |    bbox_head.head_module.convs_pred.0.bias   |    (24,)             |            |              |
# |   bbox_head.head_module.convs_pred.1         |   1.944K             |   0.276M   |   3.456K     |
# |    bbox_head.head_module.convs_pred.1.weight |    (24, 80, 1, 1)    |            |              |
# |    bbox_head.head_module.convs_pred.1.bias   |    (24,)             |            |              |
# |   bbox_head.head_module.convs_pred.2         |   3.864K             |   0.138M   |   0.864K     |
# |    bbox_head.head_module.convs_pred.2.weight |    (24, 160, 1, 1)   |            |              |
# |    bbox_head.head_module.convs_pred.2.bias   |    (24,)             |            |              |
# +----------------------------------------------+----------------------+------------+--------------+
#
# ========================================
#     Input Shape     :  [1, 3, 192, 192]
#     Model Flops     :       0.126G
#   Model Parameters  :       0.945M
# ========================================
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# 09/04 01:34:42 - mmengine - INFO - Optimizer groups: 88 .bias, 88 conv.weight, 85 other
# Loads checkpoint by local backend from path: Gesture_Detection_Swift-YOLO_192/pretrain.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: backbone.stem.bn.weight, backbone.stem.bn.bias, backbone.stem.bn.running_mean, backbone.stem.bn.running_var, backbone.stem.bn.num_batches_tracked, backbone.stem.conv.weight, backbone.stage1.0.bn.weight, backbone.stage1.0.bn.bias, backbone.stage1.0.bn.running_mean, backbone.stage1.0.bn.running_var, backbone.stage1.0.bn.num_batches_tracked, backbone.stage1.0.conv.weight, backbone.stage1.1.main_conv.bn.weight, backbone.stage1.1.main_conv.bn.bias, backbone.stage1.1.main_conv.bn.running_mean, backbone.stage1.1.main_conv.bn.running_var, backbone.stage1.1.main_conv.bn.num_batches_tracked, backbone.stage1.1.short_conv.bn.weight, backbone.stage1.1.short_conv.bn.bias, backbone.stage1.1.short_conv.bn.running_mean, backbone.stage1.1.short_conv.bn.running_var, backbone.stage1.1.short_conv.bn.num_batches_tracked, backbone.stage1.1.final_conv.bn.weight, backbone.stage1.1.final_conv.bn.bias, backbone.stage1.1.final_conv.bn.running_mean, backbone.stage1.1.final_conv.bn.running_var, backbone.stage1.1.final_conv.bn.num_batches_tracked, backbone.stage1.1.blocks.0.conv1.bn.weight, backbone.stage1.1.blocks.0.conv1.bn.bias, backbone.stage1.1.blocks.0.conv1.bn.running_mean, backbone.stage1.1.blocks.0.conv1.bn.running_var, backbone.stage1.1.blocks.0.conv1.bn.num_batches_tracked, backbone.stage1.1.blocks.0.conv2.bn.weight, backbone.stage1.1.blocks.0.conv2.bn.bias, backbone.stage1.1.blocks.0.conv2.bn.running_mean, backbone.stage1.1.blocks.0.conv2.bn.running_var, backbone.stage1.1.blocks.0.conv2.bn.num_batches_tracked, backbone.stage2.0.bn.weight, backbone.stage2.0.bn.bias, backbone.stage2.0.bn.running_mean, backbone.stage2.0.bn.running_var, backbone.stage2.0.bn.num_batches_tracked, backbone.stage2.0.conv.weight, backbone.stage2.1.main_conv.bn.weight, backbone.stage2.1.main_conv.bn.bias, backbone.stage2.1.main_conv.bn.running_mean, backbone.stage2.1.main_conv.bn.running_var, backbone.stage2.1.main_conv.bn.num_batches_tracked, backbone.stage2.1.short_conv.bn.weight, backbone.stage2.1.short_conv.bn.bias, backbone.stage2.1.short_conv.bn.running_mean, backbone.stage2.1.short_conv.bn.running_var, backbone.stage2.1.short_conv.bn.num_batches_tracked, backbone.stage2.1.final_conv.bn.weight, backbone.stage2.1.final_conv.bn.bias, backbone.stage2.1.final_conv.bn.running_mean, backbone.stage2.1.final_conv.bn.running_var, backbone.stage2.1.final_conv.bn.num_batches_tracked, backbone.stage2.1.blocks.0.conv1.bn.weight, backbone.stage2.1.blocks.0.conv1.bn.bias, backbone.stage2.1.blocks.0.conv1.bn.running_mean, backbone.stage2.1.blocks.0.conv1.bn.running_var, backbone.stage2.1.blocks.0.conv1.bn.num_batches_tracked, backbone.stage2.1.blocks.0.conv2.bn.weight, backbone.stage2.1.blocks.0.conv2.bn.bias, backbone.stage2.1.blocks.0.conv2.bn.running_mean, backbone.stage2.1.blocks.0.conv2.bn.running_var, backbone.stage2.1.blocks.0.conv2.bn.num_batches_tracked, backbone.stage2.1.blocks.1.conv1.bn.weight, backbone.stage2.1.blocks.1.conv1.bn.bias, backbone.stage2.1.blocks.1.conv1.bn.running_mean, backbone.stage2.1.blocks.1.conv1.bn.running_var, backbone.stage2.1.blocks.1.conv1.bn.num_batches_tracked, backbone.stage2.1.blocks.1.conv2.bn.weight, backbone.stage2.1.blocks.1.conv2.bn.bias, backbone.stage2.1.blocks.1.conv2.bn.running_mean, backbone.stage2.1.blocks.1.conv2.bn.running_var, backbone.stage2.1.blocks.1.conv2.bn.num_batches_tracked, backbone.stage3.0.bn.weight, backbone.stage3.0.bn.bias, backbone.stage3.0.bn.running_mean, backbone.stage3.0.bn.running_var, backbone.stage3.0.bn.num_batches_tracked, backbone.stage3.0.conv.weight, backbone.stage3.1.main_conv.bn.weight, backbone.stage3.1.main_conv.bn.bias, backbone.stage3.1.main_conv.bn.running_mean, backbone.stage3.1.main_conv.bn.running_var, backbone.stage3.1.main_conv.bn.num_batches_tracked, backbone.stage3.1.short_conv.bn.weight, backbone.stage3.1.short_conv.bn.bias, backbone.stage3.1.short_conv.bn.running_mean, backbone.stage3.1.short_conv.bn.running_var, backbone.stage3.1.short_conv.bn.num ...
#
# missing keys in source state_dict: backbone.stem.conv.conv.weight, backbone.stem.conv.norm.weight, backbone.stem.conv.norm.bias, backbone.stem.conv.norm.running_mean, backbone.stem.conv.norm.running_var, backbone.stage1.0.conv.conv.weight, backbone.stage1.0.conv.norm.weight, backbone.stage1.0.conv.norm.bias, backbone.stage1.0.conv.norm.running_mean, backbone.stage1.0.conv.norm.running_var, backbone.stage1.1.main_conv.norm.weight, backbone.stage1.1.main_conv.norm.bias, backbone.stage1.1.main_conv.norm.running_mean, backbone.stage1.1.main_conv.norm.running_var, backbone.stage1.1.short_conv.norm.weight, backbone.stage1.1.short_conv.norm.bias, backbone.stage1.1.short_conv.norm.running_mean, backbone.stage1.1.short_conv.norm.running_var, backbone.stage1.1.final_conv.norm.weight, backbone.stage1.1.final_conv.norm.bias, backbone.stage1.1.final_conv.norm.running_mean, backbone.stage1.1.final_conv.norm.running_var, backbone.stage1.1.blocks.0.conv1.norm.weight, backbone.stage1.1.blocks.0.conv1.norm.bias, backbone.stage1.1.blocks.0.conv1.norm.running_mean, backbone.stage1.1.blocks.0.conv1.norm.running_var, backbone.stage1.1.blocks.0.conv2.norm.weight, backbone.stage1.1.blocks.0.conv2.norm.bias, backbone.stage1.1.blocks.0.conv2.norm.running_mean, backbone.stage1.1.blocks.0.conv2.norm.running_var, backbone.stage1.1.blocks.1.conv1.conv.weight, backbone.stage1.1.blocks.1.conv1.norm.weight, backbone.stage1.1.blocks.1.conv1.norm.bias, backbone.stage1.1.blocks.1.conv1.norm.running_mean, backbone.stage1.1.blocks.1.conv1.norm.running_var, backbone.stage1.1.blocks.1.conv2.conv.weight, backbone.stage1.1.blocks.1.conv2.norm.weight, backbone.stage1.1.blocks.1.conv2.norm.bias, backbone.stage1.1.blocks.1.conv2.norm.running_mean, backbone.stage1.1.blocks.1.conv2.norm.running_var, backbone.stage1.1.blocks.2.conv1.conv.weight, backbone.stage1.1.blocks.2.conv1.norm.weight, backbone.stage1.1.blocks.2.conv1.norm.bias, backbone.stage1.1.blocks.2.conv1.norm.running_mean, backbone.stage1.1.blocks.2.conv1.norm.running_var, backbone.stage1.1.blocks.2.conv2.conv.weight, backbone.stage1.1.blocks.2.conv2.norm.weight, backbone.stage1.1.blocks.2.conv2.norm.bias, backbone.stage1.1.blocks.2.conv2.norm.running_mean, backbone.stage1.1.blocks.2.conv2.norm.running_var, backbone.stage2.0.conv.conv.weight, backbone.stage2.0.conv.norm.weight, backbone.stage2.0.conv.norm.bias, backbone.stage2.0.conv.norm.running_mean, backbone.stage2.0.conv.norm.running_var, backbone.stage2.1.main_conv.norm.weight, backbone.stage2.1.main_conv.norm.bias, backbone.stage2.1.main_conv.norm.running_mean, backbone.stage2.1.main_conv.norm.running_var, backbone.stage2.1.short_conv.norm.weight, backbone.stage2.1.short_conv.norm.bias, backbone.stage2.1.short_conv.norm.running_mean, backbone.stage2.1.short_conv.norm.running_var, backbone.stage2.1.final_conv.norm.weight, backbone.stage2.1.final_conv.norm.bias, backbone.stage2.1.final_conv.norm.running_mean, backbone.stage2.1.final_conv.norm.running_var, backbone.stage2.1.blocks.0.conv1.norm.weight, backbone.stage2.1.blocks.0.conv1.norm.bias, backbone.stage2.1.blocks.0.conv1.norm.running_mean, backbone.stage2.1.blocks.0.conv1.norm.running_var, backbone.stage2.1.blocks.0.conv2.norm.weight, backbone.stage2.1.blocks.0.conv2.norm.bias, backbone.stage2.1.blocks.0.conv2.norm.running_mean, backbone.stage2.1.blocks.0.conv2.norm.running_var, backbone.stage2.1.blocks.1.conv1.norm.weight, backbone.stage2.1.blocks.1.conv1.norm.bias, backbone.stage2.1.blocks.1.conv1.norm.running_mean, backbone.stage2.1.blocks.1.conv1.norm.running_var, backbone.stage2.1.blocks.1.conv2.norm.weight, backbone.stage2.1.blocks.1.conv2.norm.bias, backbone.stage2.1.blocks.1.conv2.norm.running_mean, backbone.stage2.1.blocks.1.conv2.norm.running_var, backbone.stage2.1.blocks.2.conv1.conv.weight, backbone.stage2.1.blocks.2.conv1.norm.weight, backbone.stage2.1.blocks.2.conv1.norm.bias, backbone.stage2.1.blocks.2.conv1.norm.running_mean, backbone.stage2.1.blocks.2.conv1.norm.running_var, backbone.st ...
#
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: backbone.stem.bn.weight, backbone.stem.bn.bias, backbone.stem.bn.running_mean, backbone.stem.bn.running_var, backbone.stem.bn.num_batches_tracked, backbone.stem.conv.weight, backbone.stage1.0.bn.weight, backbone.stage1.0.bn.bias, backbone.stage1.0.bn.running_mean, backbone.stage1.0.bn.running_var, backbone.stage1.0.bn.num_batches_tracked, backbone.stage1.0.conv.weight, backbone.stage1.1.main_conv.bn.weight, backbone.stage1.1.main_conv.bn.bias, backbone.stage1.1.main_conv.bn.running_mean, backbone.stage1.1.main_conv.bn.running_var, backbone.stage1.1.main_conv.bn.num_batches_tracked, backbone.stage1.1.short_conv.bn.weight, backbone.stage1.1.short_conv.bn.bias, backbone.stage1.1.short_conv.bn.running_mean, backbone.stage1.1.short_conv.bn.running_var, backbone.stage1.1.short_conv.bn.num_batches_tracked, backbone.stage1.1.final_conv.bn.weight, backbone.stage1.1.final_conv.bn.bias, backbone.stage1.1.final_conv.bn.running_mean, backbone.stage1.1.final_conv.bn.running_var, backbone.stage1.1.final_conv.bn.num_batches_tracked, backbone.stage1.1.blocks.0.conv1.bn.weight, backbone.stage1.1.blocks.0.conv1.bn.bias, backbone.stage1.1.blocks.0.conv1.bn.running_mean, backbone.stage1.1.blocks.0.conv1.bn.running_var, backbone.stage1.1.blocks.0.conv1.bn.num_batches_tracked, backbone.stage1.1.blocks.0.conv2.bn.weight, backbone.stage1.1.blocks.0.conv2.bn.bias, backbone.stage1.1.blocks.0.conv2.bn.running_mean, backbone.stage1.1.blocks.0.conv2.bn.running_var, backbone.stage1.1.blocks.0.conv2.bn.num_batches_tracked, backbone.stage2.0.bn.weight, backbone.stage2.0.bn.bias, backbone.stage2.0.bn.running_mean, backbone.stage2.0.bn.running_var, backbone.stage2.0.bn.num_batches_tracked, backbone.stage2.0.conv.weight, backbone.stage2.1.main_conv.bn.weight, backbone.stage2.1.main_conv.bn.bias, backbone.stage2.1.main_conv.bn.running_mean, backbone.stage2.1.main_conv.bn.running_var, backbone.stage2.1.main_conv.bn.num_batches_tracked, backbone.stage2.1.short_conv.bn.weight, backbone.stage2.1.short_conv.bn.bias, backbone.stage2.1.short_conv.bn.running_mean, backbone.stage2.1.short_conv.bn.running_var, backbone.stage2.1.short_conv.bn.num_batches_tracked, backbone.stage2.1.final_conv.bn.weight, backbone.stage2.1.final_conv.bn.bias, backbone.stage2.1.final_conv.bn.running_mean, backbone.stage2.1.final_conv.bn.running_var, backbone.stage2.1.final_conv.bn.num_batches_tracked, backbone.stage2.1.blocks.0.conv1.bn.weight, backbone.stage2.1.blocks.0.conv1.bn.bias, backbone.stage2.1.blocks.0.conv1.bn.running_mean, backbone.stage2.1.blocks.0.conv1.bn.running_var, backbone.stage2.1.blocks.0.conv1.bn.num_batches_tracked, backbone.stage2.1.blocks.0.conv2.bn.weight, backbone.stage2.1.blocks.0.conv2.bn.bias, backbone.stage2.1.blocks.0.conv2.bn.running_mean, backbone.stage2.1.blocks.0.conv2.bn.running_var, backbone.stage2.1.blocks.0.conv2.bn.num_batches_tracked, backbone.stage2.1.blocks.1.conv1.bn.weight, backbone.stage2.1.blocks.1.conv1.bn.bias, backbone.stage2.1.blocks.1.conv1.bn.running_mean, backbone.stage2.1.blocks.1.conv1.bn.running_var, backbone.stage2.1.blocks.1.conv1.bn.num_batches_tracked, backbone.stage2.1.blocks.1.conv2.bn.weight, backbone.stage2.1.blocks.1.conv2.bn.bias, backbone.stage2.1.blocks.1.conv2.bn.running_mean, backbone.stage2.1.blocks.1.conv2.bn.running_var, backbone.stage2.1.blocks.1.conv2.bn.num_batches_tracked, backbone.stage3.0.bn.weight, backbone.stage3.0.bn.bias, backbone.stage3.0.bn.running_mean, backbone.stage3.0.bn.running_var, backbone.stage3.0.bn.num_batches_tracked, backbone.stage3.0.conv.weight, backbone.stage3.1.main_conv.bn.weight, backbone.stage3.1.main_conv.bn.bias, backbone.stage3.1.main_conv.bn.running_mean, backbone.stage3.1.main_conv.bn.running_var, backbone.stage3.1.main_conv.bn.num_batches_tracked, backbone.stage3.1.short_conv.bn.weight, backbone.stage3.1.short_conv.bn.bias, backbone.stage3.1.short_conv.bn.running_mean, backbone.stage3.1.short_conv.bn.running_var, backbone.stage3.1.short_conv.bn.num ...
#
# missing keys in source state_dict: backbone.stem.conv.conv.weight, backbone.stem.conv.norm.weight, backbone.stem.conv.norm.bias, backbone.stem.conv.norm.running_mean, backbone.stem.conv.norm.running_var, backbone.stage1.0.conv.conv.weight, backbone.stage1.0.conv.norm.weight, backbone.stage1.0.conv.norm.bias, backbone.stage1.0.conv.norm.running_mean, backbone.stage1.0.conv.norm.running_var, backbone.stage1.1.main_conv.norm.weight, backbone.stage1.1.main_conv.norm.bias, backbone.stage1.1.main_conv.norm.running_mean, backbone.stage1.1.main_conv.norm.running_var, backbone.stage1.1.short_conv.norm.weight, backbone.stage1.1.short_conv.norm.bias, backbone.stage1.1.short_conv.norm.running_mean, backbone.stage1.1.short_conv.norm.running_var, backbone.stage1.1.final_conv.norm.weight, backbone.stage1.1.final_conv.norm.bias, backbone.stage1.1.final_conv.norm.running_mean, backbone.stage1.1.final_conv.norm.running_var, backbone.stage1.1.blocks.0.conv1.norm.weight, backbone.stage1.1.blocks.0.conv1.norm.bias, backbone.stage1.1.blocks.0.conv1.norm.running_mean, backbone.stage1.1.blocks.0.conv1.norm.running_var, backbone.stage1.1.blocks.0.conv2.norm.weight, backbone.stage1.1.blocks.0.conv2.norm.bias, backbone.stage1.1.blocks.0.conv2.norm.running_mean, backbone.stage1.1.blocks.0.conv2.norm.running_var, backbone.stage1.1.blocks.1.conv1.conv.weight, backbone.stage1.1.blocks.1.conv1.norm.weight, backbone.stage1.1.blocks.1.conv1.norm.bias, backbone.stage1.1.blocks.1.conv1.norm.running_mean, backbone.stage1.1.blocks.1.conv1.norm.running_var, backbone.stage1.1.blocks.1.conv2.conv.weight, backbone.stage1.1.blocks.1.conv2.norm.weight, backbone.stage1.1.blocks.1.conv2.norm.bias, backbone.stage1.1.blocks.1.conv2.norm.running_mean, backbone.stage1.1.blocks.1.conv2.norm.running_var, backbone.stage1.1.blocks.2.conv1.conv.weight, backbone.stage1.1.blocks.2.conv1.norm.weight, backbone.stage1.1.blocks.2.conv1.norm.bias, backbone.stage1.1.blocks.2.conv1.norm.running_mean, backbone.stage1.1.blocks.2.conv1.norm.running_var, backbone.stage1.1.blocks.2.conv2.conv.weight, backbone.stage1.1.blocks.2.conv2.norm.weight, backbone.stage1.1.blocks.2.conv2.norm.bias, backbone.stage1.1.blocks.2.conv2.norm.running_mean, backbone.stage1.1.blocks.2.conv2.norm.running_var, backbone.stage2.0.conv.conv.weight, backbone.stage2.0.conv.norm.weight, backbone.stage2.0.conv.norm.bias, backbone.stage2.0.conv.norm.running_mean, backbone.stage2.0.conv.norm.running_var, backbone.stage2.1.main_conv.norm.weight, backbone.stage2.1.main_conv.norm.bias, backbone.stage2.1.main_conv.norm.running_mean, backbone.stage2.1.main_conv.norm.running_var, backbone.stage2.1.short_conv.norm.weight, backbone.stage2.1.short_conv.norm.bias, backbone.stage2.1.short_conv.norm.running_mean, backbone.stage2.1.short_conv.norm.running_var, backbone.stage2.1.final_conv.norm.weight, backbone.stage2.1.final_conv.norm.bias, backbone.stage2.1.final_conv.norm.running_mean, backbone.stage2.1.final_conv.norm.running_var, backbone.stage2.1.blocks.0.conv1.norm.weight, backbone.stage2.1.blocks.0.conv1.norm.bias, backbone.stage2.1.blocks.0.conv1.norm.running_mean, backbone.stage2.1.blocks.0.conv1.norm.running_var, backbone.stage2.1.blocks.0.conv2.norm.weight, backbone.stage2.1.blocks.0.conv2.norm.bias, backbone.stage2.1.blocks.0.conv2.norm.running_mean, backbone.stage2.1.blocks.0.conv2.norm.running_var, backbone.stage2.1.blocks.1.conv1.norm.weight, backbone.stage2.1.blocks.1.conv1.norm.bias, backbone.stage2.1.blocks.1.conv1.norm.running_mean, backbone.stage2.1.blocks.1.conv1.norm.running_var, backbone.stage2.1.blocks.1.conv2.norm.weight, backbone.stage2.1.blocks.1.conv2.norm.bias, backbone.stage2.1.blocks.1.conv2.norm.running_mean, backbone.stage2.1.blocks.1.conv2.norm.running_var, backbone.stage2.1.blocks.2.conv1.conv.weight, backbone.stage2.1.blocks.2.conv1.norm.weight, backbone.stage2.1.blocks.2.conv1.norm.bias, backbone.stage2.1.blocks.2.conv1.norm.running_mean, backbone.stage2.1.blocks.2.conv1.norm.running_var, backbone.st ...
#
# ------------------------------------------------------------------------------------------------------------------------
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      1/10     2.3536    0.6803    0.2176    1.4557   0:16:29  : 100%|█████████| 404/404 [01:48<00:00,  3.74it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      2/10     2.0999    0.5802    0.1923    1.3273   0:14:41  : 100%|█████████| 404/404 [01:49<00:00,  3.69it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      3/10     1.9751    0.5615    0.1921    1.2215   0:12:41  : 100%|█████████| 404/404 [01:45<00:00,  3.83it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      4/10     1.8616    0.5423    0.1884    1.1309   0:10:53  : 100%|█████████| 404/404 [01:49<00:00,  3.69it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      5/10     1.8087    0.5294    0.1871    1.0922   0:09:03  : 100%|█████████| 404/404 [01:47<00:00,  3.77it/s]
#
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#    Mode     Epoch   data_time    time      eta
#    val       5/10     0.0478    0.1966   0:00:00  : 100%|███████████████████████████████| 36/36 [00:04<00:00,  8.76it/s]
# Loading and preparing results...
# DONE (t=0.79s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=4.50s).
# Accumulating evaluation results...
# DONE (t=2.10s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.040
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.074
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.360
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.473
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.153
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.510
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      6/10     1.746     0.5077    0.1827    1.0557   0:07:18  : 100%|█████████| 404/404 [01:53<00:00,  3.56it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      7/10     1.6985    0.494     0.1804    1.0241   0:05:30  : 100%|█████████| 404/404 [01:53<00:00,  3.55it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      8/10     1.6533    0.4819    0.1753    0.9961   0:03:41  : 100%|█████████| 404/404 [01:52<00:00,  3.59it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train      9/10     1.6299    0.4763    0.1763    0.9773   0:01:50  : 100%|█████████| 404/404 [01:51<00:00,  3.63it/s]
#
# ------------------------------------------------------------------------------------------------------------------------
#
#    Mode     Epoch      loss    loss_cls  loss_obj loss_bbox    eta
#   train     10/10     1.5997    0.4644    0.1753    0.9599   0:00:00  : 100%|█████████| 404/404 [01:53<00:00,  3.56it/s]
#
#
#    Mode     Epoch   data_time    time   coco/bbox_mAPcoco/bbox_mAP_50coco/bbox_mAP_75coco/bbox_mAP_scoco/bbox_mAP_mcoco/bbox_mAP_l   eta
#    val      10/10     0.0159    0.1716    0.066     0.167      0.04      0.0      0.018     0.074    0:00:00  : 100%|█|
# Loading and preparing results...
# DONE (t=0.53s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=2.17s).
# Accumulating evaluation results...
# DONE (t=1.18s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.076
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.163
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.561

# %% [markdown]
# ## 📦Export the model
# After training, you can export the model to the format for deployment. SSCMA supports exporting to ONNX, and TensorFlow Lite at present.
# You can also refer to the [documentation](https://sensecraftma.seeed.cc/tutorials/export/overview) for more details.
#
# ```bash
# python3 tools/export.py \
#     "<CONFIG_FILE_PATH>" \
#     "<CHECKPOINT_FILE_PATH>"
# ```

# %%
import os
with open('Gesture_Detection_Swift-YOLO_192/last_checkpoint', 'r') as f:
	os.environ['CHECKPOINT_FILE_PATH'] = f.read()

# %%
# !sscma.export configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py $CHECKPOINT_FILE_PATH --cfg-options  \
    work_dir=Gesture_Detection_Swift-YOLO_192 \
    num_classes=3 \
    epochs=10  \
    height=192 \
    width=192 \
    data_root=Gesture_Detection_Swift-YOLO_192/dataset/ \
    load_from=Gesture_Detection_Swift-YOLO_192/pretrain.pth
# Out:
# Using automatically generated input type (from config 'swift_yolo_tiny_1xb16_300e_coco.py'): image
# Using automatically generated input shape (from config 'swift_yolo_tiny_1xb16_300e_coco.py'): [1, 3, 192, 192]
# 09/04 01:56:42 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1640227542
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1640227542
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 09/04 01:56:43 - mmengine - INFO - Config:
# affine_scale = 0.5
# albu_train_transforms = [
#     dict(p=0.01, type='Blur'),
#     dict(p=0.01, type='MedianBlur'),
#     dict(p=0.01, type='ToGray'),
#     dict(p=0.01, type='CLAHE'),
# ]
# anchors = [
#     [
#         (
#             10,
#             13,
#         ),
#         (
#             16,
#             30,
#         ),
#         (
#             33,
#             23,
#         ),
#     ],
#     [
#         (
#             30,
#             61,
#         ),
#         (
#             62,
#             45,
#         ),
#         (
#             59,
#             119,
#         ),
#     ],
#     [
#         (
#             116,
#             90,
#         ),
#         (
#             156,
#             198,
#         ),
#         (
#             373,
#             326,
#         ),
#     ],
# ]
# batch = 16
# batch_shapes_cfg = dict(
#     batch_size=1,
#     extra_pad_ratio=0.5,
#     img_size=192,
#     size_divisor=32,
#     type='BatchShapePolicy')
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0001,
#         priority=49,
#         strict_load=False,
#         type='EMAHook',
#         update_buffers=True),
# ]
# data_root = 'Gesture_Detection_Swift-YOLO_192/dataset/'
# dataset_type = 'sscma.CustomYOLOv5CocoDataset'
# deepen_factor = 0.33
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=100, type='sscma.TextLoggerHook'),
#     param_scheduler=dict(
#         lr_factor=0.01,
#         max_epochs=10,
#         scheduler_type='linear',
#         type='YOLOv5ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='mmdet.DetVisualizationHook'))
# default_scope = 'sscma'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# epochs = 10
# height = 192
# imgsz = (
#     192,
#     192,
# )
# input_type = 'image'
# load_from = 'Gesture_Detection_Swift-YOLO_192/pretrain.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 0.05
# loss_cls_weight = 0.5
# loss_obj_weight = 1.0
# lr = 0.01
# lr_factor = 0.01
# max_keep_ckpts = 3
# model = dict(
#     backbone=dict(
#         act_cfg=dict(inplace=True, type='ReLU'),
#         deepen_factor=0.33,
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         type='YOLOv5CSPDarknet',
#         widen_factor=0.15),
#     bbox_head=dict(
#         head_module=dict(
#             featmap_strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             in_channels=[
#                 256,
#                 512,
#                 1024,
#             ],
#             num_base_priors=3,
#             num_classes=3,
#             type='sscma.DetHead',
#             widen_factor=0.15),
#         loss_bbox=dict(
#             bbox_format='xywh',
#             eps=1e-07,
#             iou_mode='ciou',
#             loss_weight=0.05,
#             reduction='mean',
#             return_iou=True,
#             type='IoULoss'),
#         loss_cls=dict(
#             loss_weight=0.01875,
#             reduction='mean',
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True),
#         loss_obj=dict(
#             loss_weight=0.09000000000000001,
#             reduction='mean',
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True),
#         obj_level_weights=[
#             4.0,
#             1.0,
#             0.4,
#         ],
#         prior_generator=dict(
#             base_sizes=[
#                 [
#                     (
#                         10,
#                         13,
#                     ),
#                     (
#                         16,
#                         30,
#                     ),
#                     (
#                         33,
#                         23,
#                     ),
#                 ],
#                 [
#                     (
#                         30,
#                         61,
#                     ),
#                     (
#                         62,
#                         45,
#                     ),
#                     (
#                         59,
#                         119,
#                     ),
#                 ],
#                 [
#                     (
#                         116,
#                         90,
#                     ),
#                     (
#                         156,
#                         198,
#                     ),
#                     (
#                         373,
#                         326,
#                     ),
#                 ],
#             ],
#             strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             type='mmdet.YOLOAnchorGenerator'),
#         prior_match_thr=4.0,
#         type='sscma.YOLOV5Head'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             0.0,
#             0.0,
#             0.0,
#         ],
#         std=[
#             255.0,
#             255.0,
#             255.0,
#         ],
#         type='mmdet.DetDataPreprocessor'),
#     neck=dict(
#         act_cfg=dict(inplace=True, type='ReLU'),
#         deepen_factor=0.33,
#         in_channels=[
#             256,
#             512,
#             1024,
#         ],
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         num_csp_blocks=3,
#         out_channels=[
#             256,
#             512,
#             1024,
#         ],
#         type='YOLOv5PAFPN',
#         widen_factor=0.15),
#     test_cfg=dict(
#         max_per_img=300,
#         multi_label=True,
#         nms=dict(iou_threshold=0.65, type='nms'),
#         nms_pre=30000,
#         score_thr=0.001),
#     type='sscma.YOLODetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# momentum = 0.937
# norm_cfg = dict(eps=0.001, momentum=0.03, type='BN')
# num_classes = 3
# num_det_layers = 3
# obj_level_weights = [
#     4.0,
#     1.0,
#     0.4,
# ]
# optim_wrapper = dict(
#     constructor='YOLOv5OptimizerConstructor',
#     optimizer=dict(
#         batch_size_per_gpu=16,
#         lr=0.01,
#         momentum=0.937,
#         nesterov=True,
#         type='SGD',
#         weight_decay=0.0005),
#     type='OptimWrapper')
# param_scheduler = None
# persistent_workers = True
# pre_transform = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
# ]
# prior_match_thr = 4.0
# resume = False
# save_interval = 5
# strides = [
#     8,
#     16,
#     32,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=16,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         batch_shapes_cfg=dict(
#             batch_size=1,
#             extra_pad_ratio=0.5,
#             img_size=192,
#             size_divisor=32,
#             type='BatchShapePolicy'),
#         data_prefix=dict(img='valid/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(scale=(
#                 192,
#                 192,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     192,
#                     192,
#                 ),
#                 type='sscma.LetterResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='sscma.CustomYOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file=
#     'Gesture_Detection_Swift-YOLO_192/dataset/valid/_annotations.coco.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# test_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(scale=(
#         192,
#         192,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=False,
#         pad_val=dict(img=114),
#         scale=(
#             192,
#             192,
#         ),
#         type='sscma.LetterResize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'pad_param',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_ann = 'train/_annotations.coco.json'
# train_cfg = dict(max_epochs=10, type='EpochBasedTrainLoop', val_interval=5)
# train_data = 'train/'
# train_dataloader = dict(
#     batch_size=16,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         data_prefix=dict(img='train/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 _scope_='sscma',
#                 img_scale=(
#                     192,
#                     192,
#                 ),
#                 pad_val=114.0,
#                 pre_transform=[
#                     dict(
#                         file_client_args=dict(backend='disk'),
#                         type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                 ],
#                 type='Mosaic'),
#             dict(
#                 border=(
#                     -96,
#                     -96,
#                 ),
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='sscma.CustomYOLOv5CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         _scope_='sscma',
#         img_scale=(
#             192,
#             192,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='Mosaic'),
#     dict(
#         border=(
#             -96,
#             -96,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# val_ann = 'valid/_annotations.coco.json'
# val_batch = 16
# val_cfg = dict(type='ValLoop')
# val_data = 'valid/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='valid/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(scale=(
#                 192,
#                 192,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     192,
#                     192,
#                 ),
#                 type='sscma.LetterResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='sscma.CustomYOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     'Gesture_Detection_Swift-YOLO_192/dataset/valid/_annotations.coco.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# val_interval = 5
# val_workers = 2
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='sscma.FomoLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# weight_decay = 0.0005
# widen_factor = 0.15
# width = 192
# work_dir = 'Gesture_Detection_Swift-YOLO_192'
# workers = 2
#
# ()
# {'vis_backends': [{'type': 'LocalVisBackend'}, {'type': 'TensorboardVisBackend'}], 'save_dir': '/content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/20240904_015641'}
# 2024-09-04 01:56:44.121965: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 01:56:44.142762: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 01:56:44.149036: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-04 01:56:44.164657: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 01:56:45.293511: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 09/04 01:56:48 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 09/04 01:56:48 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_val_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# Loads checkpoint by local backend from path: /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10.pth
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# WARNING (tinynn.graph.tracer) Constant generation is experimental and may yield error
# WARNING (tinynn.graph.tracer) Constant generation is experimental and may yield error
# /usr/local/lib/python3.10/dist-packages/torch/ao/quantization/observer.py:214: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
#   0%|                     | 0/100 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 100%|███████████| 100/100 [00:12<00:00,  7.88it/s]
# /usr/local/lib/python3.10/dist-packages/torch/ao/quantization/observer.py:1209: UserWarning: must run observer before calling calculate_qparams.                                    Returning default scale and zero point
#   warnings.warn(
# /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/yolodetector_q.py:1043: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   as_tensor_0_f = torch.as_tensor(8, dtype=torch.float32, device=device_1_f)
# /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/yolodetector_q.py:1114: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   as_tensor_1_f = torch.as_tensor(16, dtype=torch.float32, device=device_3_f)
# /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/yolodetector_q.py:1185: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   as_tensor_2_f = torch.as_tensor(32, dtype=torch.float32, device=device_5_f)
# WARNING (tinynn.converter.operators.torch.prim) 1616 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) 1625 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) 1662 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) 1670 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) 1706 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) 1714 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# INFO (tinynn.converter.base) Generated model saved to /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_int8.tflite
# Warning: No configuration file specified. Using a default of ['/usr/local/lib/python3.10/dist-packages/ethosu/config_files/Arm/vela.ini']. Compilation may be invalid or non-optimal.
# Warning: No system configuration specified. Using a default of Ethos_U55_High_End_Embedded. Compilation may be invalid or non-optimal.
# Warning: No memory mode specified. Using a default of Shared_Sram. Compilation may be invalid or non-optimal.
# Warning: TRANSPOSE 'contiguous_0_f.1' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 3, 8, 576] and permutation is: [0 1 3 2]
# Warning: TRANSPOSE '2855' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 24, 24, 24] and permutation is: [0 3 1 2]
# Info: PADV2 'input.37_transform_2' is a CPU only op
# Info: PADV2 'input.39_transform_2' is a CPU only op
# Info: PADV2 '2678_transform_2' is a CPU only op
# Warning: TRANSPOSE 'contiguous_1_f.1' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 3, 8, 144] and permutation is: [0 1 3 2]
# Warning: TRANSPOSE '2860' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 12, 12, 24] and permutation is: [0 3 1 2]
# Warning: TRANSPOSE 'contiguous_2_f.1' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 3, 8, 36] and permutation is: [0 1 3 2]
# Warning: TRANSPOSE '2865' is not supported on the NPU. Placing on CPU instead
#  - The following shape/permutations are supported for transpose:
#         When ifm rank is 2: WxC -> CxW
#         When ifm rank is 3: HxWxC -> WxHxC, 1xWxC -> 1xCxW, Hx1xC -> Cx1xH
#         When ifm rank is 4: 1xHxWxC -> 1xWxHxC, 1x1xWxC -> 1x1xCxW, 1xHx1xC -> 1xCx1xW
#    Op has ifm_shape: [1, 6, 6, 24] and permutation is: [0 3 1 2]
#
# Network summary for epoch_10_int8
# Accelerator configuration                Ethos_U55_64
# System configuration             Ethos_U55_High_End_Embedded
# Memory mode                               Shared_Sram
# Accelerator clock                                 500 MHz
# Design peak SRAM bandwidth                       3.73 GB/s
# Design peak Off-chip Flash bandwidth             0.47 GB/s
#
# Total SRAM used                                258.92 KiB
# Total Off-chip Flash used                     1174.08 KiB
#
# CPU operators = 9 (4.6%)
# NPU operators = 187 (95.4%)
#
# Average SRAM bandwidth                           0.80 GB/s
# Input   SRAM bandwidth                           3.66 MB/batch
# Weight  SRAM bandwidth                           5.32 MB/batch
# Output  SRAM bandwidth                           2.11 MB/batch
# Total   SRAM bandwidth                          11.12 MB/batch
# Total   SRAM bandwidth            per input     11.12 MB/inference (batch size 1)
#
# Average Off-chip Flash bandwidth                 0.08 GB/s
# Input   Off-chip Flash bandwidth                 0.07 MB/batch
# Weight  Off-chip Flash bandwidth                 1.07 MB/batch
# Output  Off-chip Flash bandwidth                 0.00 MB/batch
# Total   Off-chip Flash bandwidth                 1.14 MB/batch
# Total   Off-chip Flash bandwidth  per input      1.14 MB/inference (batch size 1)
#
# Neural network macs                         134698608 MACs/batch
# Network Tops/s                                   0.02 Tops/s
#
# NPU cycles                                    5704355 cycles/batch
# SRAM Access cycles                             944468 cycles/batch
# DRAM Access cycles                                  0 cycles/batch
# On-chip Flash Access cycles                         0 cycles/batch
# Off-chip Flash Access cycles                  1233792 cycles/batch
# Total cycles                                  6910931 cycles/batch
#
# Batch Inference time                13.82 ms,   72.35 inferences/s (batch size 1)
#
# TFLite: Successfully export model: /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_int8.tflite
# /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   xy = (feat_xy * 2 - 0.5 + grid) * torch.as_tensor(
# WARNING (tinynn.converter.operators.torch.prim) ny.1 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) nx.1 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) ny0.1 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) nx0.1 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) ny1.1 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# WARNING (tinynn.converter.operators.torch.prim) nx1.1 is of type int64, which is unsupported in TFLite, trying to downcast to int32
# INFO (tinynn.converter.base) Generated model saved to /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float32.tflite
# Warning: No configuration file specified. Using a default of ['/usr/local/lib/python3.10/dist-packages/ethosu/config_files/Arm/vela.ini']. Compilation may be invalid or non-optimal.
# Warning: No system configuration specified. Using a default of Ethos_U55_High_End_Embedded. Compilation may be invalid or non-optimal.
# Warning: No memory mode specified. Using a default of Shared_Sram. Compilation may be invalid or non-optimal.
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '670_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: inputs.1, fuse_attr_319_reshape, 670_te_transform
# Warning: Unsupported TensorFlow Lite semantics for PAD '670_te_transform_1_te_transform_2'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 670_te_transform, 670_te_transform_1_te_transform_2
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '670_te_transform_1'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 670_te_transform_1_te_transform_2, fuse_attr_320_reshape, 670_te_transform_1
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '704_te_transform_1'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 670_te_transform_1, fuse_attr_322_reshape, 704_te_transform_1
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '739_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 704_te_transform_1, fuse_attr_323_reshape, 739_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_74'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 739_te_transform, fuse_attr_324_reshape, fuse_transform_74
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_76'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_74, 704_te_transform_1, fuse_transform_76
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '772_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_76, fuse_attr_325_reshape, 772_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_119'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 772_te_transform, fuse_attr_326_reshape, fuse_transform_119
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_121'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_119, fuse_transform_76, fuse_transform_121
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '805_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_121, fuse_attr_327_reshape, 805_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_143'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 805_te_transform, fuse_attr_328_reshape, fuse_transform_143
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_95'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_143, fuse_transform_121, fuse_transform_95
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_96'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 670_te_transform_1, fuse_attr_321_reshape, fuse_transform_96
# Warning: Unsupported TensorFlow Lite semantics for CONCATENATION '823_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_96, 823_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '841_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 823_te_transform, fuse_attr_329_reshape, 841_te_transform
# Warning: Unsupported TensorFlow Lite semantics for PAD '841_te_transform_1_te_transform_2'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 841_te_transform, 841_te_transform_1_te_transform_2
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '841_te_transform_1'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 841_te_transform_1_te_transform_2, fuse_attr_330_reshape, 841_te_transform_1
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '875_te_transform_1'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 841_te_transform_1, fuse_attr_332_reshape, 875_te_transform_1
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '913_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 875_te_transform_1, fuse_attr_333_reshape, 913_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_18'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 913_te_transform, fuse_attr_334_reshape, fuse_transform_18
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_20'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_18, 875_te_transform_1, fuse_transform_20
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '946_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_20, fuse_attr_335_reshape, 946_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_54'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 946_te_transform, fuse_attr_336_reshape, fuse_transform_54
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_56'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_54, fuse_transform_20, fuse_transform_56
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '979_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_56, fuse_attr_337_reshape, 979_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_69'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 979_te_transform, fuse_attr_338_reshape, fuse_transform_69
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_71'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_69, fuse_transform_56, fuse_transform_71
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1012_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_71, fuse_attr_339_reshape, 1012_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_41'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1012_te_transform, fuse_attr_340_reshape, fuse_transform_41
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_43'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_41, fuse_transform_71, fuse_transform_43
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1045_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_43, fuse_attr_341_reshape, 1045_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_83'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1045_te_transform, fuse_attr_342_reshape, fuse_transform_83
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_85'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_83, fuse_transform_43, fuse_transform_85
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1078_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_85, fuse_attr_343_reshape, 1078_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_86'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1078_te_transform, fuse_attr_344_reshape, fuse_transform_86
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_89'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_86, fuse_transform_85, fuse_transform_89
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_90'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 841_te_transform_1, fuse_attr_331_reshape, fuse_transform_90
# Warning: Unsupported TensorFlow Lite semantics for CONCATENATION '1096_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_90, 1096_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1096_te_transform_1'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1096_te_transform, fuse_attr_345_reshape, 1096_te_transform_1
# Warning: Unsupported TensorFlow Lite semantics for PAD '1114_te_transform_1_te_transform_2'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1096_te_transform_1, 1114_te_transform_1_te_transform_2
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1114_te_transform_1'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1114_te_transform_1_te_transform_2, fuse_attr_346_reshape, 1114_te_transform_1
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1148_te_transform_1'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1114_te_transform_1, fuse_attr_348_reshape, 1148_te_transform_1
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1189_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1148_te_transform_1, fuse_attr_349_reshape, 1189_te_transform
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D 'fuse_transform_110'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: 1189_te_transform, fuse_attr_350_reshape, fuse_transform_110
# Warning: Unsupported TensorFlow Lite semantics for ADD 'fuse_transform_112'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
#    Op has tensors with missing quantization parameters: fuse_transform_110, 1148_te_transform_1, fuse_transform_112
# Warning: Unsupported TensorFlow Lite semantics for CONV_2D '1222_te_transform'. Placing on CPU instead
#  - Input(s), Output and Weight tensors must have quantization parameters
# ...
#   %/Constant_36_output_0 : Long(6, 1, strides=[1, 1], requires_grad=0, device=cpu) = onnx::Constant[value= 0  1  2  3  4  5 [ CPULongType{6,1} ], onnx_name="/Constant_36"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /usr/local/lib/python3.10/dist-packages/torch/functional.py:504:0
#   %/Expand_8_output_0 : Long(6, 6, strides=[1, 0], requires_grad=0, device=cpu) = onnx::Expand[onnx_name="/Expand_8"](%/Constant_36_output_0, %/Constant_35_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector::
#   %/Constant_37_output_0 : Long(1, 6, strides=[6, 1], requires_grad=0, device=cpu) = onnx::Constant[value= 0  1  2  3  4  5 [ CPULongType{1,6} ], onnx_name="/Constant_37"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /usr/local/lib/python3.10/dist-packages/torch/functional.py:504:0
#   %/Expand_9_output_0 : Long(6, 6, strides=[0, 1], requires_grad=0, device=cpu) = onnx::Expand[onnx_name="/Expand_9"](%/Constant_37_output_0, %/Constant_35_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector::
#   %/Unsqueeze_4_output_0 : Long(6, 6, 1, strides=[6, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[2], onnx_name="/Unsqueeze_4"](%/Expand_9_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Unsqueeze_5_output_0 : Long(6, 6, 1, strides=[6, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[2], onnx_name="/Unsqueeze_5"](%/Expand_8_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Concat_4_output_0 : Long(6, 6, 2, strides=[12, 2, 1], requires_grad=0, device=cpu) = onnx::Concat[axis=2, onnx_name="/Concat_4"](%/Unsqueeze_4_output_0, %/Unsqueeze_5_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Constant_38_output_0 : Long(5, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value= 1  1  6  6  2 [ CPULongType{5} ], onnx_name="/Constant_38"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Constant_39_output_0 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={5}, onnx_name="/Constant_39"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/ConstantOfShape_4_output_0 : Long(5, strides=[1], device=cpu) = onnx::ConstantOfShape[value={1}, onnx_name="/ConstantOfShape_4"](%/Constant_39_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Constant_40_output_0 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}, onnx_name="/Constant_40"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Mul_16_output_0 : Long(5, strides=[1], device=cpu) = onnx::Mul[onnx_name="/Mul_16"](%/ConstantOfShape_4_output_0, %/Constant_40_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Equal_4_output_0 : Bool(5, strides=[1], device=cpu) = onnx::Equal[onnx_name="/Equal_4"](%/Constant_38_output_0, %/Mul_16_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Where_4_output_0 : Long(5, strides=[1], device=cpu) = onnx::Where[onnx_name="/Where_4"](%/Equal_4_output_0, %/ConstantOfShape_4_output_0, %/Constant_38_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Expand_10_output_0 : Long(1, 1, 6, 6, 2, strides=[72, 72, 12, 2, 1], requires_grad=0, device=cpu) = onnx::Expand[onnx_name="/Expand_10"](%/Concat_4_output_0, %/Where_4_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Constant_41_output_0 : Long(4, strides=[1], device=cpu) = onnx::Constant[value= 1  1 -1  2 [ CPULongType{4} ], onnx_name="/Constant_41"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Reshape_7_output_0 : Long(1, 1, 36, 2, strides=[72, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Reshape[onnx_name="/Reshape_7"](%/Expand_10_output_0, %/Constant_41_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Cast_8_output_0 : Float(1, 1, 36, 2, strides=[72, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Cast[to=1, onnx_name="/Cast_8"](%/Reshape_7_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %/Cast_9_output_0 : Float(1, 1, 36, 2, strides=[72, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Cast[to=1, onnx_name="/Cast_9"](%/Cast_8_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:143:0
#   %onnx::Expand_1061 : Long(1, 3, 1, 2, strides=[6, 2, 2, 1], requires_grad=0, device=cpu) = onnx::Constant[value=(1,1,.,.) =    116   90  (1,2,.,.) =    156  198  (1,3,.,.) =    373  326 [ CPULongType{1,3,1,2} ]]()
#   %/Constant_42_output_0 : Long(4, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value=  1   3  36   2 [ CPULongType{4} ], onnx_name="/Constant_42"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/Constant_43_output_0 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value={4}, onnx_name="/Constant_43"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/ConstantOfShape_5_output_0 : Long(4, strides=[1], device=cpu) = onnx::ConstantOfShape[value={1}, onnx_name="/ConstantOfShape_5"](%/Constant_43_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/Constant_44_output_0 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}, onnx_name="/Constant_44"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/Mul_17_output_0 : Long(4, strides=[1], device=cpu) = onnx::Mul[onnx_name="/Mul_17"](%/ConstantOfShape_5_output_0, %/Constant_44_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/Equal_5_output_0 : Bool(4, strides=[1], device=cpu) = onnx::Equal[onnx_name="/Equal_5"](%/Constant_42_output_0, %/Mul_17_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/Where_5_output_0 : Long(4, strides=[1], device=cpu) = onnx::Where[onnx_name="/Where_5"](%/Equal_5_output_0, %/ConstantOfShape_5_output_0, %/Constant_42_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/Expand_11_output_0 : Long(1, 3, 36, 2, strides=[6, 2, 0, 1], requires_grad=0, device=cpu) = onnx::Expand[onnx_name="/Expand_11"](%onnx::Expand_1061, %/Where_5_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:148:0
#   %/Cast_10_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Cast[to=1, onnx_name="/Cast_10"](%/Expand_11_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:149:0
#   %/Cast_11_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Cast[to=1, onnx_name="/Cast_11"](%/Cast_10_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:150:0
#   %/Split_2_output_0 : Float(1, 3, 36, 2, strides=[864, 288, 8, 1], requires_grad=0, device=cpu), %/Split_2_output_1 : Float(1, 3, 36, 2, strides=[864, 288, 8, 1], requires_grad=0, device=cpu), %/Split_2_output_2 : Float(1, 3, 36, 4, strides=[864, 288, 8, 1], requires_grad=0, device=cpu) = onnx::Split[axis=-1, split=[2, 2, 4], onnx_name="/Split_2"](%/Transpose_2_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:803:0
#   %/Constant_45_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/Constant_45"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125:0
#   %/Mul_18_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/Mul_18"](%/Split_2_output_0, %/Constant_45_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125:0
#   %/Constant_46_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.5}, onnx_name="/Constant_46"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125:0
#   %/Sub_2_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Sub[onnx_name="/Sub_2"](%/Mul_18_output_0, %/Constant_46_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125:0
#   %/Add_2_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Add[onnx_name="/Add_2"](%/Sub_2_output_0, %/Cast_9_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125:0
#   %/Constant_47_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={32}, onnx_name="/Constant_47"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125:0
#   %/Mul_19_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/Mul_19"](%/Add_2_output_0, %/Constant_47_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:125:0
#   %/Constant_48_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}, onnx_name="/Constant_48"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:128:0
#   %/Mul_20_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/Mul_20"](%/Split_2_output_1, %/Constant_48_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:128:0
#   %/Mul_21_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/Mul_21"](%/Mul_20_output_0, %/Mul_20_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:129:0
#   %/Mul_22_output_0 : Float(1, 3, 36, 2, strides=[216, 72, 2, 1], requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/Mul_22"](%/Mul_21_output_0, %/Cast_11_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:130:0
#   %/Constant_49_output_0 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={100}, onnx_name="/Constant_49"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:131:0
#   %/Mul_23_output_0 : Float(1, 3, 36, 4, strides=[432, 144, 4, 1], requires_grad=0, device=cpu) = onnx::Mul[onnx_name="/Mul_23"](%/Split_2_output_2, %/Constant_49_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:131:0
#   %/Concat_5_output_0 : Float(1, 3, 36, 8, strides=[864, 288, 8, 1], requires_grad=0, device=cpu) = onnx::Concat[axis=-1, onnx_name="/Concat_5"](%/Mul_19_output_0, %/Mul_22_output_0, %/Mul_23_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:132:0
#   %/Constant_50_output_0 : Long(3, strides=[1], requires_grad=0, device=cpu) = onnx::Constant[value= 1 -1  8 [ CPULongType{3} ], onnx_name="/Constant_50"](), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:133:0
#   %/Reshape_8_output_0 : Float(1, 108, 8, strides=[864, 8, 1], requires_grad=0, device=cpu) = onnx::Reshape[onnx_name="/Reshape_8"](%/Concat_5_output_0, %/Constant_50_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:133:0
#   %output : Float(1, 2268, 8, strides=[18144, 8, 1], requires_grad=0, device=cpu) = onnx::Concat[axis=1, onnx_name="/Concat_6"](%/Reshape_4_output_0, %/Reshape_6_output_0, %/Reshape_8_output_0), scope: sscma.models.detectors.yolov5_detector.YOLODetector:: # /content/ModelAssistant/sscma/models/heads/yolov5_head.py:135:0
#   return (%output)
#
# ============= Diagnostic Run torch.onnx.export version 2.0.0+cu117 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: Successfully export model: /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float32.onnx
# pnnxparam = /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float.pnnx.param
# pnnxbin = /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float.pnnx.bin
# pnnxpy = /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float.pnnx.py
# pnnxonnx = /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float.pnnx.onnx
# ncnnparam = /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float.ncnn.param
# ncnnbin = /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float.ncnn.bin
# ncnnpy = /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_float.ncnn.py
# fp16 = 1
# optlevel = 2
# device = cpu
# inputshape = [1,3,192,192]f32
# inputshape2 =
# customop =
# moduleop =
# ############# pass_level0
# inline module = sscma.models.backbones.csp_darknet.YOLOv5CSPDarknet
# inline module = sscma.models.base.conv_module.ConvModule
# inline module = sscma.models.base.general.ConvNormActivation
# inline module = sscma.models.layers.csp_layer.CSPLayer
# inline module = sscma.models.layers.csp_layer.DarknetBottleneck
# inline module = sscma.models.layers.sppf.SPPFBottleneck
# inline module = sscma.models.necks.fpn.YOLOv5PAFPN
# inline module = torch.nn.modules.linear.Identity
# inline module = sscma.models.backbones.csp_darknet.YOLOv5CSPDarknet
# inline module = sscma.models.base.conv_module.ConvModule
# inline module = sscma.models.base.general.ConvNormActivation
# inline module = sscma.models.layers.csp_layer.CSPLayer
# inline module = sscma.models.layers.csp_layer.DarknetBottleneck
# inline module = sscma.models.layers.sppf.SPPFBottleneck
# inline module = sscma.models.necks.fpn.YOLOv5PAFPN
# inline module = torch.nn.modules.linear.Identity
#
# ----------------
#
# ############# pass_level1
# ############# pass_level2
# ############# pass_level3
# ############# pass_level4
# ############# pass_level5
# ############# pass_ncnn

# %% [markdown]
# ### 📝Evaluate the model
# After exporting the model, you can evaluate the model on the test dataset.
# You can also refer to the [documentation](https://sensecraftma.seeed.cc/tutorials/export/overview) for more details.
#
#
# ```bash
# python3 tools/inference.py \
#     "<CONFIG_FILE_PATH>" \
#     "<CHECKPOINT_FILE_PATH>"
# ```

# %% [markdown]
# ### Evaluate the PyTorch model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}.pth \
--cfg-options  \
    work_dir=Gesture_Detection_Swift-YOLO_192 \
    num_classes=3 \
    epochs=10  \
    height=192 \
    width=192 \
    data_root=Gesture_Detection_Swift-YOLO_192/dataset/ \
    load_from=Gesture_Detection_Swift-YOLO_192/pretrain.pth

# %% [markdown]
# ### Evaluate the ONNX model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}_float32.onnx \
--cfg-options  \
    work_dir=Gesture_Detection_Swift-YOLO_192 \
    num_classes=3 \
    epochs=10  \
    height=192 \
    width=192 \
    data_root=Gesture_Detection_Swift-YOLO_192/dataset/ \
    load_from=Gesture_Detection_Swift-YOLO_192/pretrain.pth

# %% [markdown]
# ### Evaluate the TFLite FLOAT32 model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}_float32.tflite \
--cfg-options  \
    work_dir=Gesture_Detection_Swift-YOLO_192 \
    num_classes=3 \
    epochs=10  \
    height=192 \
    width=192 \
    data_root=Gesture_Detection_Swift-YOLO_192/dataset/ \
    load_from=Gesture_Detection_Swift-YOLO_192/pretrain.pth

# %% [markdown]
# ### Evaluate the TFLite INT8 model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}_int8.tflite \
--cfg-options  \
    work_dir=Gesture_Detection_Swift-YOLO_192 \
    num_classes=3 \
    epochs=10  \
    height=192 \
    width=192 \
    data_root=Gesture_Detection_Swift-YOLO_192/dataset/ \
    load_from=Gesture_Detection_Swift-YOLO_192/pretrain.pth
# Out:
# Using task type from config: mmdet
# Using dump path from checkpoint: /content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_int8.pkl
# 09/04 01:58:51 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 2024081525
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.0+cu117
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.5
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.7, CUDNN_VERSION=8.5.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu117
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 2024081525
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 09/04 01:58:51 - mmengine - INFO - Config:
# affine_scale = 0.5
# albu_train_transforms = [
#     dict(p=0.01, type='Blur'),
#     dict(p=0.01, type='MedianBlur'),
#     dict(p=0.01, type='ToGray'),
#     dict(p=0.01, type='CLAHE'),
# ]
# anchors = [
#     [
#         (
#             10,
#             13,
#         ),
#         (
#             16,
#             30,
#         ),
#         (
#             33,
#             23,
#         ),
#     ],
#     [
#         (
#             30,
#             61,
#         ),
#         (
#             62,
#             45,
#         ),
#         (
#             59,
#             119,
#         ),
#     ],
#     [
#         (
#             116,
#             90,
#         ),
#         (
#             156,
#             198,
#         ),
#         (
#             373,
#             326,
#         ),
#     ],
# ]
# batch = 16
# batch_shapes_cfg = dict(
#     batch_size=1,
#     extra_pad_ratio=0.5,
#     img_size=192,
#     size_divisor=32,
#     type='BatchShapePolicy')
# custom_hooks = [
#     dict(
#         ema_type='ExpMomentumEMA',
#         momentum=0.0001,
#         priority=49,
#         strict_load=False,
#         type='EMAHook',
#         update_buffers=True),
# ]
# data_root = 'Gesture_Detection_Swift-YOLO_192/dataset/'
# dataset_type = 'sscma.CustomYOLOv5CocoDataset'
# deepen_factor = 0.33
# default_hooks = dict(
#     checkpoint=dict(
#         interval=5, max_keep_ckpts=3, save_best='auto', type='CheckpointHook'),
#     logger=dict(interval=100, type='sscma.TextLoggerHook'),
#     param_scheduler=dict(
#         lr_factor=0.01,
#         max_epochs=10,
#         scheduler_type='linear',
#         type='YOLOv5ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='mmdet.DetVisualizationHook'))
# default_scope = 'sscma'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# epochs = 10
# height = 192
# imgsz = (
#     192,
#     192,
# )
# input_type = 'image'
# launcher = 'none'
# load_from = 'Gesture_Detection_Swift-YOLO_192/pretrain.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# loss_bbox_weight = 0.05
# loss_cls_weight = 0.5
# loss_obj_weight = 1.0
# lr = 0.01
# lr_factor = 0.01
# max_keep_ckpts = 3
# model = dict(
#     backbone=dict(
#         act_cfg=dict(inplace=True, type='ReLU'),
#         deepen_factor=0.33,
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         type='YOLOv5CSPDarknet',
#         widen_factor=0.15),
#     bbox_head=dict(
#         head_module=dict(
#             featmap_strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             in_channels=[
#                 256,
#                 512,
#                 1024,
#             ],
#             num_base_priors=3,
#             num_classes=3,
#             type='sscma.DetHead',
#             widen_factor=0.15),
#         loss_bbox=dict(
#             bbox_format='xywh',
#             eps=1e-07,
#             iou_mode='ciou',
#             loss_weight=0.05,
#             reduction='mean',
#             return_iou=True,
#             type='IoULoss'),
#         loss_cls=dict(
#             loss_weight=0.01875,
#             reduction='mean',
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True),
#         loss_obj=dict(
#             loss_weight=0.09000000000000001,
#             reduction='mean',
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True),
#         obj_level_weights=[
#             4.0,
#             1.0,
#             0.4,
#         ],
#         prior_generator=dict(
#             base_sizes=[
#                 [
#                     (
#                         10,
#                         13,
#                     ),
#                     (
#                         16,
#                         30,
#                     ),
#                     (
#                         33,
#                         23,
#                     ),
#                 ],
#                 [
#                     (
#                         30,
#                         61,
#                     ),
#                     (
#                         62,
#                         45,
#                     ),
#                     (
#                         59,
#                         119,
#                     ),
#                 ],
#                 [
#                     (
#                         116,
#                         90,
#                     ),
#                     (
#                         156,
#                         198,
#                     ),
#                     (
#                         373,
#                         326,
#                     ),
#                 ],
#             ],
#             strides=[
#                 8,
#                 16,
#                 32,
#             ],
#             type='mmdet.YOLOAnchorGenerator'),
#         prior_match_thr=4.0,
#         type='sscma.YOLOV5Head'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             0.0,
#             0.0,
#             0.0,
#         ],
#         std=[
#             255.0,
#             255.0,
#             255.0,
#         ],
#         type='mmdet.DetDataPreprocessor'),
#     neck=dict(
#         act_cfg=dict(inplace=True, type='ReLU'),
#         deepen_factor=0.33,
#         in_channels=[
#             256,
#             512,
#             1024,
#         ],
#         norm_cfg=dict(eps=0.001, momentum=0.03, type='BN'),
#         num_csp_blocks=3,
#         out_channels=[
#             256,
#             512,
#             1024,
#         ],
#         type='YOLOv5PAFPN',
#         widen_factor=0.15),
#     test_cfg=dict(
#         max_per_img=300,
#         multi_label=True,
#         nms=dict(iou_threshold=0.65, type='nms'),
#         nms_pre=30000,
#         score_thr=0.001),
#     type='sscma.YOLODetector')
# model_test_cfg = dict(
#     max_per_img=300,
#     multi_label=True,
#     nms=dict(iou_threshold=0.65, type='nms'),
#     nms_pre=30000,
#     score_thr=0.001)
# momentum = 0.937
# norm_cfg = dict(eps=0.001, momentum=0.03, type='BN')
# num_classes = 3
# num_det_layers = 3
# obj_level_weights = [
#     4.0,
#     1.0,
#     0.4,
# ]
# optim_wrapper = dict(
#     constructor='YOLOv5OptimizerConstructor',
#     optimizer=dict(
#         batch_size_per_gpu=16,
#         lr=0.01,
#         momentum=0.937,
#         nesterov=True,
#         type='SGD',
#         weight_decay=0.0005),
#     type='OptimWrapper')
# param_scheduler = None
# persistent_workers = True
# pre_transform = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
# ]
# prior_match_thr = 4.0
# resume = False
# save_interval = 5
# strides = [
#     8,
#     16,
#     32,
# ]
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=16,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         batch_shapes_cfg=dict(
#             batch_size=1,
#             extra_pad_ratio=0.5,
#             img_size=192,
#             size_divisor=32,
#             type='BatchShapePolicy'),
#         data_prefix=dict(img='valid/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(scale=(
#                 192,
#                 192,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     192,
#                     192,
#                 ),
#                 type='sscma.LetterResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='sscma.CustomYOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(
#         ann_file=
#         'Gesture_Detection_Swift-YOLO_192/dataset/valid/_annotations.coco.json',
#         metric='bbox',
#         proposal_nums=(
#             100,
#             1,
#             10,
#         ),
#         type='mmdet.CocoMetric'),
#     dict(
#         out_file_path=
#         '/content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/epoch_10_int8.pkl',
#         type='DumpResults'),
# ]
# test_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(scale=(
#         192,
#         192,
#     ), type='YOLOv5KeepRatioResize'),
#     dict(
#         allow_scale_up=False,
#         pad_val=dict(img=114),
#         scale=(
#             192,
#             192,
#         ),
#         type='sscma.LetterResize'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#             'pad_param',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# train_ann = 'train/_annotations.coco.json'
# train_cfg = dict(max_epochs=10, type='EpochBasedTrainLoop', val_interval=5)
# train_data = 'train/'
# train_dataloader = dict(
#     batch_size=16,
#     dataset=dict(
#         ann_file='train/_annotations.coco.json',
#         data_prefix=dict(img='train/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         filter_cfg=dict(filter_empty_gt=False, min_size=32),
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 _scope_='sscma',
#                 img_scale=(
#                     192,
#                     192,
#                 ),
#                 pad_val=114.0,
#                 pre_transform=[
#                     dict(
#                         file_client_args=dict(backend='disk'),
#                         type='LoadImageFromFile'),
#                     dict(type='LoadAnnotations', with_bbox=True),
#                 ],
#                 type='Mosaic'),
#             dict(
#                 border=(
#                     -96,
#                     -96,
#                 ),
#                 border_val=(
#                     114,
#                     114,
#                     114,
#                 ),
#                 max_rotate_degree=0.0,
#                 max_shear_degree=0.0,
#                 scaling_ratio_range=(
#                     0.5,
#                     1.5,
#                 ),
#                 type='YOLOv5RandomAffine'),
#             dict(
#                 bbox_params=dict(
#                     format='pascal_voc',
#                     label_fields=[
#                         'gt_bboxes_labels',
#                         'gt_ignore_flags',
#                     ],
#                     type='BboxParams'),
#                 keymap=dict(gt_bboxes='bboxes', img='image'),
#                 transforms=[
#                     dict(p=0.01, type='Blur'),
#                     dict(p=0.01, type='MedianBlur'),
#                     dict(p=0.01, type='ToGray'),
#                     dict(p=0.01, type='CLAHE'),
#                 ],
#                 type='mmdet.Albu'),
#             dict(type='YOLOv5HSVRandomAug'),
#             dict(prob=0.5, type='mmdet.RandomFlip'),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'flip',
#                     'flip_direction',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         type='sscma.CustomYOLOv5CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         _scope_='sscma',
#         img_scale=(
#             192,
#             192,
#         ),
#         pad_val=114.0,
#         pre_transform=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#         ],
#         type='Mosaic'),
#     dict(
#         border=(
#             -96,
#             -96,
#         ),
#         border_val=(
#             114,
#             114,
#             114,
#         ),
#         max_rotate_degree=0.0,
#         max_shear_degree=0.0,
#         scaling_ratio_range=(
#             0.5,
#             1.5,
#         ),
#         type='YOLOv5RandomAffine'),
#     dict(
#         bbox_params=dict(
#             format='pascal_voc',
#             label_fields=[
#                 'gt_bboxes_labels',
#                 'gt_ignore_flags',
#             ],
#             type='BboxParams'),
#         keymap=dict(gt_bboxes='bboxes', img='image'),
#         transforms=[
#             dict(p=0.01, type='Blur'),
#             dict(p=0.01, type='MedianBlur'),
#             dict(p=0.01, type='ToGray'),
#             dict(p=0.01, type='CLAHE'),
#         ],
#         type='mmdet.Albu'),
#     dict(type='YOLOv5HSVRandomAug'),
#     dict(prob=0.5, type='mmdet.RandomFlip'),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'flip',
#             'flip_direction',
#         ),
#         type='mmdet.PackDetInputs'),
# ]
# val_ann = 'valid/_annotations.coco.json'
# val_batch = 16
# val_cfg = dict(type='ValLoop')
# val_data = 'valid/'
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='valid/_annotations.coco.json',
#         batch_shapes_cfg=None,
#         data_prefix=dict(img='valid/'),
#         data_root='Gesture_Detection_Swift-YOLO_192/dataset/',
#         pipeline=[
#             dict(
#                 file_client_args=dict(backend='disk'),
#                 type='LoadImageFromFile'),
#             dict(scale=(
#                 192,
#                 192,
#             ), type='YOLOv5KeepRatioResize'),
#             dict(
#                 allow_scale_up=False,
#                 pad_val=dict(img=114),
#                 scale=(
#                     192,
#                     192,
#                 ),
#                 type='sscma.LetterResize'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                     'pad_param',
#                 ),
#                 type='mmdet.PackDetInputs'),
#         ],
#         test_mode=True,
#         type='sscma.CustomYOLOv5CocoDataset'),
#     drop_last=False,
#     num_workers=1,
#     persistent_workers=True,
#     pin_memory=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file=
#     'Gesture_Detection_Swift-YOLO_192/dataset/valid/_annotations.coco.json',
#     metric='bbox',
#     proposal_nums=(
#         100,
#         1,
#         10,
#     ),
#     type='mmdet.CocoMetric')
# val_interval = 5
# val_workers = 2
# vis_backends = [
#     dict(type='LocalVisBackend'),
#     dict(type='TensorboardVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='sscma.FomoLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#     ])
# weight_decay = 0.0005
# widen_factor = 0.15
# width = 192
# work_dir = 'Gesture_Detection_Swift-YOLO_192'
# workers = 2
#
# ()
# {'vis_backends': [{'type': 'LocalVisBackend'}, {'type': 'TensorboardVisBackend'}], 'save_dir': '/content/ModelAssistant/Gesture_Detection_Swift-YOLO_192/20240904_015850'}
# 2024-09-04 01:58:52.868441: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 01:58:52.889045: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 01:58:52.895480: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-04 01:58:52.911198: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-04 01:58:54.066101: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 09/04 01:58:57 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 09/04 01:58:57 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_val_epoch:
# (9           ) YOLOv5ParamSchedulerHook
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) TextLoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
#   0% 0/576 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 09/04 01:58:58 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 09/04 01:58:58 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 100% 576/576 [00:10<00:00, 55.45it/s]
# 09/04 01:59:08 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.05s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.273
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.054
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.038
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.122
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.189
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.044
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.209
# 09/04 01:59:08 - mmengine - INFO - bbox_mAP_copypaste: 0.110 0.273 0.054 0.000 0.038 0.122
# {'coco/bbox_mAP': 0.11, 'coco/bbox_mAP_50': 0.273, 'coco/bbox_mAP_75': 0.054, 'coco/bbox_mAP_s': 0.0, 'coco/bbox_mAP_m': 0.038, 'coco/bbox_mAP_l': 0.122}
# FPS: 82.707164 fram/s

# %% [markdown]
# ## 🤖 Deploy the model
# After model training, evaluation and export, you can deploy the model to your device. You can refer to [Documentation](https://sensecraftma.seeed.cc/deploy/overview) for more details.

# %%
# %ls -lh Gesture_Detection_Swift-YOLO_192/

# %% [markdown]
# ### Thanks for Trying Out SSCMA 🎉
#
# Congratulations, you have completed this tutorial. If you are interested in more application scenarios or our projects, please feel free to give [SSCMA](https://github.com/Seeed-Studio/ModelAssistant) a star ✨ on GitHub.
#
# If you have any questions about this tutorial, please also feel free to [submit an issue](https://github.com/Seeed-Studio/ModelAssistant/issues).
